# %% [markdown]
# # テーマ：CIFAR-10データセットを畳み込みニューラルネットワーク（CNN）で学習する

# %% [markdown]
# ## 制約
# * 全体の実行時間は60分以内

# %% [markdown]
# ## 今回参考にしたもの
# * [Deep Residual Learning for Image Recognition](https://arxiv.org/abs/1512.03385)
# * [practice on CIFAR10 with Keras](https://github.com/jerett/Keras-CIFAR10)

# %% [markdown]
# ## 1. Prepare dataset

# %%
import tensorflow as tf

# print(tfds.list_builders())
# dataset, info = tfds.load('cifar10', as_supervised = True, with_info = True, batch_size = -1)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

dataset_test = (x_test, y_test) 
dataset_train = (x_train, y_train)
# print(info)

# %%
import numpy as np

train_x = dataset_train[0] / 255
train_y = dataset_train[1].squeeze()
test_x = dataset_test[0] / 255
test_y = dataset_test[1].squeeze()

# Per-pixel Mean Subtraction
# mean_image = np.mean(train_x, axis=0)
# train_x -= mean_image
# test_x -= mean_image

# %%
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
# Out:
# (50000, 32, 32, 3) (50000,)
# (10000, 32, 32, 3) (10000,)

# %% [markdown]
# ## 2. Data Augmentation

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()
# ZCA whiteningなどを行う場合が以下の実行が必要
# datagen.fit(train_x)
# datagen_for_test.fit(test_x)

# %% [markdown]
# ## 3. Define model

# %%
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2

n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=(32, 32, 3))
x = Conv2D(channels[0], kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", strides=strides, kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)        
        if subsampling:
            x = Conv2D(c, kernel_size=(1, 1), strides=(2, 2), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, activation=tf.nn.softmax, kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)
model.type = "resnet" + str(6 * n + 2)

# %%
# from io import StringIO
# import re

# with StringIO() as buf:
#     model.summary(print_fn=lambda x: buf.write(x + "\n"))
#     summary = buf.getvalue()
# print(summary)
# re1 = re.match(r"(.|\s)*Total params: ", summary)
# re2 = re.match(r"(.|\s)*Total params: [\d|,]+", summary)
# total_params = summary[re1.end():re2.end()]

# %% [markdown]
# ## 4. Prepare training

# %%
from tensorflow.keras.optimizers import Adam, SGD

# lr = 0.001
# optimizer = Adam(learning_rate=lr)
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# !pip install hyperdash
# from hyperdash import monitor_cell
# !hyperdash signup --github

# %%
# from hyperdash import Experiment
# exp = Experiment("ResNet-for-CIFAR-10-with-Keras")

# %%
from tensorflow.keras.callbacks import Callback
import time

# class Hyperdash(Callback):
#     def __init__(self, entries, exp):
#         super(Hyperdash, self).__init__()
#         self.entries = entries
#         self.exp = exp

#     def on_epoch_end(self, epoch, logs=None):
#         for entry in self.entries:
#             log = logs.get(entry)            
#             if log is not None:
#                 self.exp.metric(entry, log)

class LearningController(Callback):
    def __init__(self, num_epoch=0, learn_minute=0):
        self.num_epoch = num_epoch
        self.learn_second = learn_minute * 60
        if self.learn_second > 0:
            print("Leraning rate is controled by time.")
        elif self.num_epoch > 0:
            print("Leraning rate is controled by epoch.")
        
    def on_train_begin(self, logs=None):
        if self.learn_second > 0:
            self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        if self.learn_second > 0:
            current_time = time.time()
            if current_time - self.start_time > self.learn_second:
                self.model.stop_training = True
                print("Time is up.")
                return

            if current_time - self.start_time > self.learn_second / 2:
                self.model.optimizer.lr = lr * 0.1            
            if current_time - self.start_time > self.learn_second * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                
        elif self.num_epoch > 0:
            if epoch > self.num_epoch / 2:
                self.model.optimizer.lr = lr * 0.1            
            if epoch > self.num_epoch * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                    
        print('lr:%.2e' % self.model.optimizer.lr.value())

# %%
num_epoch = 182
learn_minute = 120

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# hyperdash = Hyperdash(["val_loss", "loss", "val_accuracy", "accuracy"], exp)
checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", 
                             monitor="val_loss", 
                             verbose=1, 
                             save_best_only=True)
learning_controller = LearningController(num_epoch)
callbacks = [checkpoint, learning_controller]
# Out:
# Leraning rate is controled by epoch.

# %% [markdown]
# ## 5. Train

# %%
batch_size = 128
# number_train = info.splits["train"].num_examples
# number_test = info.splits["test"].num_examples
number_train = train_x.shape[0]
number_test = test_x.shape[0]

# %%
number_test, number_train
# Out:
# (10000, 50000)

# %%
# import json

# exp.param("Model type", model.type)
# exp.param("Total params", total_params)
# exp.param("Optimizer", optimizer)
# exp.param("Leraning rate", lr)
# exp.param("Datagen", json.dumps(datagen_parameters))
# exp.param("Batch size", batch_size)
# exp.param("Number of epoch", num_epoch)
# exp.param("Learn minute", learn_minute)

# %%
model.fit(datagen.flow(train_x, 
                         train_y, 
                         batch_size=batch_size),
            epochs=num_epoch, 
            steps_per_epoch=number_train//batch_size, 
            validation_data=datagen_for_test.flow(test_x, 
                                                  test_y, 
                                                  batch_size=batch_size), 
            validation_steps=number_test//batch_size,
            verbose=1,                    
            callbacks=callbacks)
# exp.end()
# Out:
# Epoch 1/182
# 390/390 [==============================] - ETA: 0s - loss: 2.9073 - accuracy: 0.1997
# Epoch 1: val_loss improved from inf to 4.07265, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 70s 116ms/step - loss: 2.9073 - accuracy: 0.1997 - val_loss: 4.0726 - val_accuracy: 0.1575
# Epoch 2/182
# 390/390 [==============================] - ETA: 0s - loss: 2.2477 - accuracy: 0.3583
# Epoch 2: val_loss improved from 4.07265 to 2.58327, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 45s 113ms/step - loss: 2.2477 - accuracy: 0.3583 - val_loss: 2.5833 - val_accuracy: 0.2844
# Epoch 3/182
# 390/390 [==============================] - ETA: 0s - loss: 2.0479 - accuracy: 0.4094
# Epoch 3: val_loss improved from 2.58327 to 2.36682, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 44s 112ms/step - loss: 2.0479 - accuracy: 0.4094 - val_loss: 2.3668 - val_accuracy: 0.2984
# Epoch 4/182
# 390/390 [==============================] - ETA: 0s - loss: 1.9206 - accuracy: 0.4391
# Epoch 4: val_loss improved from 2.36682 to 2.11108, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 44s 112ms/step - loss: 1.9206 - accuracy: 0.4391 - val_loss: 2.1111 - val_accuracy: 0.4086
# Epoch 5/182
# 390/390 [==============================] - ETA: 0s - loss: 1.7987 - accuracy: 0.4669
# Epoch 5: val_loss improved from 2.11108 to 1.87281, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 43s 111ms/step - loss: 1.7987 - accuracy: 0.4669 - val_loss: 1.8728 - val_accuracy: 0.4597
# Epoch 6/182
# 390/390 [==============================] - ETA: 0s - loss: 1.7123 - accuracy: 0.4913
# Epoch 6: val_loss did not improve from 1.87281
# lr:1.00e-01
# 390/390 [==============================] - 44s 112ms/step - loss: 1.7123 - accuracy: 0.4913 - val_loss: 2.3495 - val_accuracy: 0.3707
# Epoch 7/182
# 390/390 [==============================] - ETA: 0s - loss: 1.6033 - accuracy: 0.5223
# Epoch 7: val_loss improved from 1.87281 to 1.65229, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 44s 113ms/step - loss: 1.6033 - accuracy: 0.5223 - val_loss: 1.6523 - val_accuracy: 0.4997
# Epoch 8/182
# 390/390 [==============================] - ETA: 0s - loss: 1.5143 - accuracy: 0.5485
# Epoch 8: val_loss did not improve from 1.65229
# lr:1.00e-01
# 390/390 [==============================] - 43s 111ms/step - loss: 1.5143 - accuracy: 0.5485 - val_loss: 2.3596 - val_accuracy: 0.4050
# Epoch 9/182
# 390/390 [==============================] - ETA: 0s - loss: 1.4244 - accuracy: 0.5745
# Epoch 9: val_loss improved from 1.65229 to 1.43306, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 43s 111ms/step - loss: 1.4244 - accuracy: 0.5745 - val_loss: 1.4331 - val_accuracy: 0.5817
# Epoch 10/182
# 390/390 [==============================] - ETA: 0s - loss: 1.3495 - accuracy: 0.5999
# Epoch 10: val_loss improved from 1.43306 to 1.42801, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 44s 113ms/step - loss: 1.3495 - accuracy: 0.5999 - val_loss: 1.4280 - val_accuracy: 0.5965
# Epoch 11/182
# 390/390 [==============================] - ETA: 0s - loss: 1.2808 - accuracy: 0.6229
# Epoch 11: val_loss did not improve from 1.42801
# lr:1.00e-01
# 390/390 [==============================] - 43s 111ms/step - loss: 1.2808 - accuracy: 0.6229 - val_loss: 2.2575 - val_accuracy: 0.4402
# Epoch 12/182
# 390/390 [==============================] - ETA: 0s - loss: 1.2428 - accuracy: 0.6344
# Epoch 12: val_loss improved from 1.42801 to 1.21288, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 43s 110ms/step - loss: 1.2428 - accuracy: 0.6344 - val_loss: 1.2129 - val_accuracy: 0.6591
# Epoch 13/182
# 390/390 [==============================] - ETA: 0s - loss: 1.1942 - accuracy: 0.6512
# Epoch 13: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 1.1942 - accuracy: 0.6512 - val_loss: 1.3809 - val_accuracy: 0.6240
# Epoch 14/182
# 390/390 [==============================] - ETA: 0s - loss: 1.1499 - accuracy: 0.6662
# Epoch 14: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 1.1499 - accuracy: 0.6662 - val_loss: 1.2620 - val_accuracy: 0.6242
# Epoch 15/182
# 390/390 [==============================] - ETA: 0s - loss: 1.1183 - accuracy: 0.6764
# Epoch 15: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 1.1183 - accuracy: 0.6764 - val_loss: 4.1412 - val_accuracy: 0.2206
# Epoch 16/182
# 390/390 [==============================] - ETA: 0s - loss: 1.0910 - accuracy: 0.6871
# Epoch 16: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 1.0910 - accuracy: 0.6871 - val_loss: 1.5355 - val_accuracy: 0.5838
# Epoch 17/182
# 390/390 [==============================] - ETA: 0s - loss: 1.0577 - accuracy: 0.6992
# Epoch 17: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 50s 127ms/step - loss: 1.0577 - accuracy: 0.6992 - val_loss: 1.8252 - val_accuracy: 0.5435
# Epoch 18/182
# 390/390 [==============================] - ETA: 0s - loss: 1.0400 - accuracy: 0.7044
# Epoch 18: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 1.0400 - accuracy: 0.7044 - val_loss: 1.4050 - val_accuracy: 0.6198
# Epoch 19/182
# 390/390 [==============================] - ETA: 0s - loss: 1.0116 - accuracy: 0.7149
# Epoch 19: val_loss did not improve from 1.21288
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 1.0116 - accuracy: 0.7149 - val_loss: 2.8927 - val_accuracy: 0.4259
# Epoch 20/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.7194
# Epoch 20: val_loss improved from 1.21288 to 0.95371, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.9975 - accuracy: 0.7194 - val_loss: 0.9537 - val_accuracy: 0.7449
# Epoch 21/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9869 - accuracy: 0.7259
# Epoch 21: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 50s 127ms/step - loss: 0.9869 - accuracy: 0.7259 - val_loss: 1.3957 - val_accuracy: 0.6378
# Epoch 22/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9629 - accuracy: 0.7340
# Epoch 22: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.9629 - accuracy: 0.7340 - val_loss: 1.1012 - val_accuracy: 0.6981
# Epoch 23/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9768 - accuracy: 0.7317
# Epoch 23: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.9768 - accuracy: 0.7317 - val_loss: 1.4624 - val_accuracy: 0.6300
# Epoch 24/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9490 - accuracy: 0.7433
# Epoch 24: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.9490 - accuracy: 0.7433 - val_loss: 0.9988 - val_accuracy: 0.7379
# Epoch 25/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9392 - accuracy: 0.7470
# Epoch 25: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.9392 - accuracy: 0.7470 - val_loss: 1.0235 - val_accuracy: 0.7366
# Epoch 26/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9261 - accuracy: 0.7526
# Epoch 26: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.9261 - accuracy: 0.7526 - val_loss: 1.0001 - val_accuracy: 0.7329
# Epoch 27/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9054 - accuracy: 0.7577
# Epoch 27: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 132ms/step - loss: 0.9054 - accuracy: 0.7577 - val_loss: 1.4760 - val_accuracy: 0.6382
# Epoch 28/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9041 - accuracy: 0.7593
# Epoch 28: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.9041 - accuracy: 0.7593 - val_loss: 1.0843 - val_accuracy: 0.7219
# Epoch 29/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.7621
# Epoch 29: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8925 - accuracy: 0.7621 - val_loss: 1.1813 - val_accuracy: 0.6952
# Epoch 30/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8927 - accuracy: 0.7658
# Epoch 30: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.8927 - accuracy: 0.7658 - val_loss: 1.0117 - val_accuracy: 0.7418
# Epoch 31/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.7693
# Epoch 31: val_loss did not improve from 0.95371
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8824 - accuracy: 0.7693 - val_loss: 0.9986 - val_accuracy: 0.7525
# Epoch 32/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8675 - accuracy: 0.7756
# Epoch 32: val_loss improved from 0.95371 to 0.92856, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 51s 132ms/step - loss: 0.8675 - accuracy: 0.7756 - val_loss: 0.9286 - val_accuracy: 0.7671
# Epoch 33/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8672 - accuracy: 0.7753
# Epoch 33: val_loss did not improve from 0.92856
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8672 - accuracy: 0.7753 - val_loss: 1.6387 - val_accuracy: 0.6169
# Epoch 34/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9383 - accuracy: 0.7602
# Epoch 34: val_loss did not improve from 0.92856
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.9383 - accuracy: 0.7602 - val_loss: 0.9631 - val_accuracy: 0.7686
# Epoch 35/182
# 390/390 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.7710
# Epoch 35: val_loss improved from 0.92856 to 0.88681, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.9271 - accuracy: 0.7710 - val_loss: 0.8868 - val_accuracy: 0.7869
# Epoch 36/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8937 - accuracy: 0.7806
# Epoch 36: val_loss did not improve from 0.88681
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8937 - accuracy: 0.7806 - val_loss: 0.9788 - val_accuracy: 0.7689
# Epoch 37/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8774 - accuracy: 0.7825
# Epoch 37: val_loss improved from 0.88681 to 0.84741, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 52s 133ms/step - loss: 0.8774 - accuracy: 0.7825 - val_loss: 0.8474 - val_accuracy: 0.8058
# Epoch 38/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8718 - accuracy: 0.7871
# Epoch 38: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.8718 - accuracy: 0.7871 - val_loss: 1.5841 - val_accuracy: 0.6289
# Epoch 39/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8607 - accuracy: 0.7891
# Epoch 39: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.8607 - accuracy: 0.7891 - val_loss: 0.8748 - val_accuracy: 0.7985
# Epoch 40/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8520 - accuracy: 0.7906
# Epoch 40: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8520 - accuracy: 0.7906 - val_loss: 0.9868 - val_accuracy: 0.7596
# Epoch 41/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8468 - accuracy: 0.7915
# Epoch 41: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8468 - accuracy: 0.7915 - val_loss: 1.5074 - val_accuracy: 0.6239
# Epoch 42/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8420 - accuracy: 0.7949
# Epoch 42: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.8420 - accuracy: 0.7949 - val_loss: 1.1395 - val_accuracy: 0.7293
# Epoch 43/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8404 - accuracy: 0.7953
# Epoch 43: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8404 - accuracy: 0.7953 - val_loss: 1.0278 - val_accuracy: 0.7596
# Epoch 44/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.7979
# Epoch 44: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.8292 - accuracy: 0.7979 - val_loss: 1.0861 - val_accuracy: 0.7247
# Epoch 45/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8200 - accuracy: 0.7997
# Epoch 45: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8200 - accuracy: 0.7997 - val_loss: 0.9905 - val_accuracy: 0.7622
# Epoch 46/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8179 - accuracy: 0.8027
# Epoch 46: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8179 - accuracy: 0.8027 - val_loss: 1.0726 - val_accuracy: 0.7531
# Epoch 47/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.8038
# Epoch 47: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8135 - accuracy: 0.8038 - val_loss: 1.1093 - val_accuracy: 0.7492
# Epoch 48/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8177 - accuracy: 0.8034
# Epoch 48: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.8177 - accuracy: 0.8034 - val_loss: 0.9649 - val_accuracy: 0.7697
# Epoch 49/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8128 - accuracy: 0.8055
# Epoch 49: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.8128 - accuracy: 0.8055 - val_loss: 1.1466 - val_accuracy: 0.7179
# Epoch 50/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8010 - accuracy: 0.8102
# Epoch 50: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8010 - accuracy: 0.8102 - val_loss: 1.0320 - val_accuracy: 0.7441
# Epoch 51/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7943 - accuracy: 0.8116
# Epoch 51: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7943 - accuracy: 0.8116 - val_loss: 1.2166 - val_accuracy: 0.7126
# Epoch 52/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8028 - accuracy: 0.8102
# Epoch 52: val_loss did not improve from 0.84741
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8028 - accuracy: 0.8102 - val_loss: 1.0281 - val_accuracy: 0.7608
# Epoch 53/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7924 - accuracy: 0.8154
# Epoch 53: val_loss improved from 0.84741 to 0.83724, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7924 - accuracy: 0.8154 - val_loss: 0.8372 - val_accuracy: 0.8067
# Epoch 54/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7894 - accuracy: 0.8141
# Epoch 54: val_loss improved from 0.83724 to 0.82143, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 52s 133ms/step - loss: 0.7894 - accuracy: 0.8141 - val_loss: 0.8214 - val_accuracy: 0.8029
# Epoch 55/182
# 390/390 [==============================] - ETA: 0s - loss: 0.8040 - accuracy: 0.8091
# Epoch 55: val_loss did not improve from 0.82143
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.8040 - accuracy: 0.8091 - val_loss: 1.3967 - val_accuracy: 0.6834
# Epoch 56/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7879 - accuracy: 0.8142
# Epoch 56: val_loss improved from 0.82143 to 0.81485, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7879 - accuracy: 0.8142 - val_loss: 0.8149 - val_accuracy: 0.8210
# Epoch 57/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7876 - accuracy: 0.8150
# Epoch 57: val_loss did not improve from 0.81485
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7876 - accuracy: 0.8150 - val_loss: 1.2219 - val_accuracy: 0.7212
# Epoch 58/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7819 - accuracy: 0.8194
# Epoch 58: val_loss improved from 0.81485 to 0.79581, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7819 - accuracy: 0.8194 - val_loss: 0.7958 - val_accuracy: 0.8216
# Epoch 59/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7855 - accuracy: 0.8171
# Epoch 59: val_loss did not improve from 0.79581
# lr:1.00e-01
# 390/390 [==============================] - 51s 132ms/step - loss: 0.7855 - accuracy: 0.8171 - val_loss: 1.0396 - val_accuracy: 0.7434
# Epoch 60/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7783 - accuracy: 0.8222
# Epoch 60: val_loss did not improve from 0.79581
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7783 - accuracy: 0.8222 - val_loss: 1.7522 - val_accuracy: 0.6312
# Epoch 61/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7746 - accuracy: 0.8228
# Epoch 61: val_loss did not improve from 0.79581
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7746 - accuracy: 0.8228 - val_loss: 0.9260 - val_accuracy: 0.7878
# Epoch 62/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7725 - accuracy: 0.8232
# Epoch 62: val_loss improved from 0.79581 to 0.76431, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7725 - accuracy: 0.8232 - val_loss: 0.7643 - val_accuracy: 0.8353
# Epoch 63/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7797 - accuracy: 0.8217
# Epoch 63: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7797 - accuracy: 0.8217 - val_loss: 1.4683 - val_accuracy: 0.6813
# Epoch 64/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7709 - accuracy: 0.8245
# Epoch 64: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7709 - accuracy: 0.8245 - val_loss: 1.0525 - val_accuracy: 0.7695
# Epoch 65/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7670 - accuracy: 0.8265
# Epoch 65: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7670 - accuracy: 0.8265 - val_loss: 1.0449 - val_accuracy: 0.7627
# Epoch 66/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.8272
# Epoch 66: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7637 - accuracy: 0.8272 - val_loss: 1.1051 - val_accuracy: 0.7394
# Epoch 67/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7631 - accuracy: 0.8263
# Epoch 67: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7631 - accuracy: 0.8263 - val_loss: 0.9445 - val_accuracy: 0.7799
# Epoch 68/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7613 - accuracy: 0.8272
# Epoch 68: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.7613 - accuracy: 0.8272 - val_loss: 0.7983 - val_accuracy: 0.8333
# Epoch 69/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7614 - accuracy: 0.8303
# Epoch 69: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7614 - accuracy: 0.8303 - val_loss: 0.8781 - val_accuracy: 0.8027
# Epoch 70/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7607 - accuracy: 0.8305
# Epoch 70: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7607 - accuracy: 0.8305 - val_loss: 1.2625 - val_accuracy: 0.7056
# Epoch 71/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7513 - accuracy: 0.8310
# Epoch 71: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7513 - accuracy: 0.8310 - val_loss: 0.7897 - val_accuracy: 0.8312
# Epoch 72/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7515 - accuracy: 0.8332
# Epoch 72: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7515 - accuracy: 0.8332 - val_loss: 0.9204 - val_accuracy: 0.8027
# Epoch 73/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7528 - accuracy: 0.8316
# Epoch 73: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7528 - accuracy: 0.8316 - val_loss: 1.2653 - val_accuracy: 0.7182
# Epoch 74/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7513 - accuracy: 0.8343
# Epoch 74: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7513 - accuracy: 0.8343 - val_loss: 1.0651 - val_accuracy: 0.7684
# Epoch 75/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7558 - accuracy: 0.8314
# Epoch 75: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7558 - accuracy: 0.8314 - val_loss: 0.7735 - val_accuracy: 0.8359
# Epoch 76/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.8334
# Epoch 76: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7525 - accuracy: 0.8334 - val_loss: 0.8218 - val_accuracy: 0.8268
# Epoch 77/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7511 - accuracy: 0.8336
# Epoch 77: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.7511 - accuracy: 0.8336 - val_loss: 1.1039 - val_accuracy: 0.7610
# Epoch 78/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.8373
# Epoch 78: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7440 - accuracy: 0.8373 - val_loss: 0.8616 - val_accuracy: 0.8174
# Epoch 79/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7432 - accuracy: 0.8401
# Epoch 79: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 129ms/step - loss: 0.7432 - accuracy: 0.8401 - val_loss: 0.7780 - val_accuracy: 0.8411
# Epoch 80/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7526 - accuracy: 0.8360
# Epoch 80: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7526 - accuracy: 0.8360 - val_loss: 1.2144 - val_accuracy: 0.7481
# Epoch 81/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.8347
# Epoch 81: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7520 - accuracy: 0.8347 - val_loss: 0.8880 - val_accuracy: 0.8096
# Epoch 82/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7424 - accuracy: 0.8392
# Epoch 82: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.7424 - accuracy: 0.8392 - val_loss: 0.9001 - val_accuracy: 0.7938
# Epoch 83/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7415 - accuracy: 0.8400
# Epoch 83: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7415 - accuracy: 0.8400 - val_loss: 0.7693 - val_accuracy: 0.8441
# Epoch 84/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.8398
# Epoch 84: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 131ms/step - loss: 0.7474 - accuracy: 0.8398 - val_loss: 1.1519 - val_accuracy: 0.7332
# Epoch 85/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7424 - accuracy: 0.8403
# Epoch 85: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7424 - accuracy: 0.8403 - val_loss: 0.9994 - val_accuracy: 0.7692
# Epoch 86/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7409 - accuracy: 0.8395
# Epoch 86: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7409 - accuracy: 0.8395 - val_loss: 0.8189 - val_accuracy: 0.8187
# Epoch 87/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.8407
# Epoch 87: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7399 - accuracy: 0.8407 - val_loss: 0.8999 - val_accuracy: 0.7901
# Epoch 88/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.8411
# Epoch 88: val_loss did not improve from 0.76431
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7399 - accuracy: 0.8411 - val_loss: 0.9504 - val_accuracy: 0.7939
# Epoch 89/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7379 - accuracy: 0.8412
# Epoch 89: val_loss improved from 0.76431 to 0.70008, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7379 - accuracy: 0.8412 - val_loss: 0.7001 - val_accuracy: 0.8674
# Epoch 90/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7461 - accuracy: 0.8382
# Epoch 90: val_loss did not improve from 0.70008
# lr:1.00e-01
# 390/390 [==============================] - 50s 128ms/step - loss: 0.7461 - accuracy: 0.8382 - val_loss: 1.0345 - val_accuracy: 0.7833
# Epoch 91/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7386 - accuracy: 0.8431
# Epoch 91: val_loss did not improve from 0.70008
# lr:1.00e-01
# 390/390 [==============================] - 50s 129ms/step - loss: 0.7386 - accuracy: 0.8431 - val_loss: 0.8614 - val_accuracy: 0.8144
# Epoch 92/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.8414
# Epoch 92: val_loss did not improve from 0.70008
# lr:1.00e-01
# 390/390 [==============================] - 51s 130ms/step - loss: 0.7371 - accuracy: 0.8414 - val_loss: 0.7862 - val_accuracy: 0.8348
# Epoch 93/182
# 390/390 [==============================] - ETA: 0s - loss: 0.7378 - accuracy: 0.8437
# Epoch 93: val_loss did not improve from 0.70008
# lr:1.00e-02
# 390/390 [==============================] - 51s 131ms/step - loss: 0.7378 - accuracy: 0.8437 - val_loss: 0.8494 - val_accuracy: 0.8200
# Epoch 94/182
# 390/390 [==============================] - ETA: 0s - loss: 0.6418 - accuracy: 0.8754
# Epoch 94: val_loss improved from 0.70008 to 0.58399, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.6418 - accuracy: 0.8754 - val_loss: 0.5840 - val_accuracy: 0.9032
# Epoch 95/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.8940
# Epoch 95: val_loss improved from 0.58399 to 0.55311, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 131ms/step - loss: 0.5863 - accuracy: 0.8940 - val_loss: 0.5531 - val_accuracy: 0.9105
# Epoch 96/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.9011
# Epoch 96: val_loss did not improve from 0.55311
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.5601 - accuracy: 0.9011 - val_loss: 0.5558 - val_accuracy: 0.9085
# Epoch 97/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5433 - accuracy: 0.9057
# Epoch 97: val_loss improved from 0.55311 to 0.53662, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 52s 132ms/step - loss: 0.5433 - accuracy: 0.9057 - val_loss: 0.5366 - val_accuracy: 0.9130
# Epoch 98/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.9072
# Epoch 98: val_loss did not improve from 0.53662
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.5348 - accuracy: 0.9072 - val_loss: 0.5384 - val_accuracy: 0.9157
# Epoch 99/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.9098
# Epoch 99: val_loss improved from 0.53662 to 0.52191, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.5223 - accuracy: 0.9098 - val_loss: 0.5219 - val_accuracy: 0.9179
# Epoch 100/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.9090
# Epoch 100: val_loss did not improve from 0.52191
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.5196 - accuracy: 0.9090 - val_loss: 0.5378 - val_accuracy: 0.9125
# Epoch 101/182
# 390/390 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.9125
# Epoch 101: val_loss improved from 0.52191 to 0.51189, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 132ms/step - loss: 0.5066 - accuracy: 0.9125 - val_loss: 0.5119 - val_accuracy: 0.9174
# Epoch 102/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.9154
# Epoch 102: val_loss improved from 0.51189 to 0.50528, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 132ms/step - loss: 0.4956 - accuracy: 0.9154 - val_loss: 0.5053 - val_accuracy: 0.9187
# Epoch 103/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.9162
# Epoch 103: val_loss improved from 0.50528 to 0.49966, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4865 - accuracy: 0.9162 - val_loss: 0.4997 - val_accuracy: 0.9201
# Epoch 104/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4819 - accuracy: 0.9180
# Epoch 104: val_loss did not improve from 0.49966
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.4819 - accuracy: 0.9180 - val_loss: 0.5109 - val_accuracy: 0.9180
# Epoch 105/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.9185
# Epoch 105: val_loss did not improve from 0.49966
# lr:1.00e-02
# 390/390 [==============================] - 50s 128ms/step - loss: 0.4722 - accuracy: 0.9185 - val_loss: 0.5182 - val_accuracy: 0.9138
# Epoch 106/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.9203
# Epoch 106: val_loss did not improve from 0.49966
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4659 - accuracy: 0.9203 - val_loss: 0.5124 - val_accuracy: 0.9164
# Epoch 107/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.9203
# Epoch 107: val_loss did not improve from 0.49966
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4652 - accuracy: 0.9203 - val_loss: 0.5253 - val_accuracy: 0.9100
# Epoch 108/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.9227
# Epoch 108: val_loss improved from 0.49966 to 0.49260, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 132ms/step - loss: 0.4541 - accuracy: 0.9227 - val_loss: 0.4926 - val_accuracy: 0.9177
# Epoch 109/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.9230
# Epoch 109: val_loss improved from 0.49260 to 0.48350, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.4490 - accuracy: 0.9230 - val_loss: 0.4835 - val_accuracy: 0.9217
# Epoch 110/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.9266
# Epoch 110: val_loss improved from 0.48350 to 0.47615, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 132ms/step - loss: 0.4359 - accuracy: 0.9266 - val_loss: 0.4762 - val_accuracy: 0.9236
# Epoch 111/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.9267
# Epoch 111: val_loss did not improve from 0.47615
# lr:1.00e-02
# 390/390 [==============================] - 51s 131ms/step - loss: 0.4365 - accuracy: 0.9267 - val_loss: 0.4876 - val_accuracy: 0.9172
# Epoch 112/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4293 - accuracy: 0.9276
# Epoch 112: val_loss did not improve from 0.47615
# lr:1.00e-02
# 390/390 [==============================] - 51s 129ms/step - loss: 0.4293 - accuracy: 0.9276 - val_loss: 0.5002 - val_accuracy: 0.9133
# Epoch 113/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.9284
# Epoch 113: val_loss did not improve from 0.47615
# lr:1.00e-02
# 390/390 [==============================] - 50s 128ms/step - loss: 0.4241 - accuracy: 0.9284 - val_loss: 0.5002 - val_accuracy: 0.9148
# Epoch 114/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4177 - accuracy: 0.9294
# Epoch 114: val_loss improved from 0.47615 to 0.47187, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4177 - accuracy: 0.9294 - val_loss: 0.4719 - val_accuracy: 0.9236
# Epoch 115/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.9300
# Epoch 115: val_loss did not improve from 0.47187
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4170 - accuracy: 0.9300 - val_loss: 0.4761 - val_accuracy: 0.9197
# Epoch 116/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.9300
# Epoch 116: val_loss did not improve from 0.47187
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4088 - accuracy: 0.9300 - val_loss: 0.4859 - val_accuracy: 0.9158
# Epoch 117/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.9301
# Epoch 117: val_loss did not improve from 0.47187
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4065 - accuracy: 0.9301 - val_loss: 0.4819 - val_accuracy: 0.9172
# Epoch 118/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.9304
# Epoch 118: val_loss did not improve from 0.47187
# lr:1.00e-02
# 390/390 [==============================] - 50s 128ms/step - loss: 0.4054 - accuracy: 0.9304 - val_loss: 0.4946 - val_accuracy: 0.9130
# Epoch 119/182
# 390/390 [==============================] - ETA: 0s - loss: 0.4005 - accuracy: 0.9318
# Epoch 119: val_loss did not improve from 0.47187
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.4005 - accuracy: 0.9318 - val_loss: 0.4757 - val_accuracy: 0.9178
# Epoch 120/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.9319
# Epoch 120: val_loss improved from 0.47187 to 0.46544, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 131ms/step - loss: 0.3973 - accuracy: 0.9319 - val_loss: 0.4654 - val_accuracy: 0.9224
# Epoch 121/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3900 - accuracy: 0.9320
# Epoch 121: val_loss did not improve from 0.46544
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3900 - accuracy: 0.9320 - val_loss: 0.4681 - val_accuracy: 0.9187
# Epoch 122/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.9331
# Epoch 122: val_loss improved from 0.46544 to 0.45827, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3867 - accuracy: 0.9331 - val_loss: 0.4583 - val_accuracy: 0.9198
# Epoch 123/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.9348
# Epoch 123: val_loss did not improve from 0.45827
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3813 - accuracy: 0.9348 - val_loss: 0.4785 - val_accuracy: 0.9164
# Epoch 124/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.9326
# Epoch 124: val_loss did not improve from 0.45827
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3850 - accuracy: 0.9326 - val_loss: 0.4669 - val_accuracy: 0.9169
# Epoch 125/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.9350
# Epoch 125: val_loss did not improve from 0.45827
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3761 - accuracy: 0.9350 - val_loss: 0.4847 - val_accuracy: 0.9145
# Epoch 126/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3757 - accuracy: 0.9343
# Epoch 126: val_loss did not improve from 0.45827
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3757 - accuracy: 0.9343 - val_loss: 0.4753 - val_accuracy: 0.9156
# Epoch 127/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.9346
# Epoch 127: val_loss improved from 0.45827 to 0.45198, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3753 - accuracy: 0.9346 - val_loss: 0.4520 - val_accuracy: 0.9194
# Epoch 128/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.9358
# Epoch 128: val_loss did not improve from 0.45198
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3677 - accuracy: 0.9358 - val_loss: 0.4699 - val_accuracy: 0.9151
# Epoch 129/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.9365
# Epoch 129: val_loss did not improve from 0.45198
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3656 - accuracy: 0.9365 - val_loss: 0.4596 - val_accuracy: 0.9189
# Epoch 130/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.9343
# Epoch 130: val_loss did not improve from 0.45198
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3673 - accuracy: 0.9343 - val_loss: 0.4721 - val_accuracy: 0.9122
# Epoch 131/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.9389
# Epoch 131: val_loss improved from 0.45198 to 0.44779, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-02
# 390/390 [==============================] - 50s 128ms/step - loss: 0.3542 - accuracy: 0.9389 - val_loss: 0.4478 - val_accuracy: 0.9218
# Epoch 132/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.9359
# Epoch 132: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3593 - accuracy: 0.9359 - val_loss: 0.4720 - val_accuracy: 0.9157
# Epoch 133/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.9375
# Epoch 133: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3561 - accuracy: 0.9375 - val_loss: 0.4847 - val_accuracy: 0.9145
# Epoch 134/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.9364
# Epoch 134: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3528 - accuracy: 0.9364 - val_loss: 0.4504 - val_accuracy: 0.9209
# Epoch 135/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.9378
# Epoch 135: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3489 - accuracy: 0.9378 - val_loss: 0.4515 - val_accuracy: 0.9176
# Epoch 136/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.9381
# Epoch 136: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 50s 128ms/step - loss: 0.3477 - accuracy: 0.9381 - val_loss: 0.4961 - val_accuracy: 0.9112
# Epoch 137/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.9384
# Epoch 137: val_loss did not improve from 0.44779
# lr:1.00e-02
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3462 - accuracy: 0.9384 - val_loss: 0.4590 - val_accuracy: 0.9144
# Epoch 138/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.9399
# Epoch 138: val_loss did not improve from 0.44779
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.3402 - accuracy: 0.9399 - val_loss: 0.4582 - val_accuracy: 0.9150
# Epoch 139/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.9425
# Epoch 139: val_loss improved from 0.44779 to 0.41457, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 131ms/step - loss: 0.3309 - accuracy: 0.9425 - val_loss: 0.4146 - val_accuracy: 0.9262
# Epoch 140/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.9499
# Epoch 140: val_loss improved from 0.41457 to 0.41079, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 132ms/step - loss: 0.3114 - accuracy: 0.9499 - val_loss: 0.4108 - val_accuracy: 0.9284
# Epoch 141/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9517
# Epoch 141: val_loss did not improve from 0.41079
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3069 - accuracy: 0.9517 - val_loss: 0.4121 - val_accuracy: 0.9276
# Epoch 142/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3035 - accuracy: 0.9534
# Epoch 142: val_loss improved from 0.41079 to 0.40821, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3035 - accuracy: 0.9534 - val_loss: 0.4082 - val_accuracy: 0.9312
# Epoch 143/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9523
# Epoch 143: val_loss improved from 0.40821 to 0.40815, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3029 - accuracy: 0.9523 - val_loss: 0.4081 - val_accuracy: 0.9297
# Epoch 144/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.9535
# Epoch 144: val_loss did not improve from 0.40815
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3016 - accuracy: 0.9535 - val_loss: 0.4099 - val_accuracy: 0.9296
# Epoch 145/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.9517
# Epoch 145: val_loss improved from 0.40815 to 0.40765, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3020 - accuracy: 0.9517 - val_loss: 0.4077 - val_accuracy: 0.9285
# Epoch 146/182
# 390/390 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.9526
# Epoch 146: val_loss improved from 0.40765 to 0.40465, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3018 - accuracy: 0.9526 - val_loss: 0.4046 - val_accuracy: 0.9300
# Epoch 147/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.9546
# Epoch 147: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2979 - accuracy: 0.9546 - val_loss: 0.4078 - val_accuracy: 0.9316
# Epoch 148/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.9552
# Epoch 148: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2958 - accuracy: 0.9552 - val_loss: 0.4098 - val_accuracy: 0.9297
# Epoch 149/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9548
# Epoch 149: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2960 - accuracy: 0.9548 - val_loss: 0.4063 - val_accuracy: 0.9310
# Epoch 150/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.9541
# Epoch 150: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2961 - accuracy: 0.9541 - val_loss: 0.4071 - val_accuracy: 0.9319
# Epoch 151/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9546
# Epoch 151: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2937 - accuracy: 0.9546 - val_loss: 0.4078 - val_accuracy: 0.9310
# Epoch 152/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.9555
# Epoch 152: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2922 - accuracy: 0.9555 - val_loss: 0.4086 - val_accuracy: 0.9322
# Epoch 153/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9546
# Epoch 153: val_loss did not improve from 0.40465
# lr:1.00e-03
# 390/390 [==============================] - 50s 128ms/step - loss: 0.2949 - accuracy: 0.9546 - val_loss: 0.4075 - val_accuracy: 0.9312
# Epoch 154/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9542
# Epoch 154: val_loss improved from 0.40465 to 0.40333, saving model to ResNet-for-CIFAR-10-with-Keras.h5
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2947 - accuracy: 0.9542 - val_loss: 0.4033 - val_accuracy: 0.9327
# Epoch 155/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9556
# Epoch 155: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2902 - accuracy: 0.9556 - val_loss: 0.4070 - val_accuracy: 0.9321
# Epoch 156/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.9557
# Epoch 156: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2903 - accuracy: 0.9557 - val_loss: 0.4077 - val_accuracy: 0.9314
# Epoch 157/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9568
# Epoch 157: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2865 - accuracy: 0.9568 - val_loss: 0.4129 - val_accuracy: 0.9312
# Epoch 158/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.9578
# Epoch 158: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2855 - accuracy: 0.9578 - val_loss: 0.4082 - val_accuracy: 0.9317
# Epoch 159/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9558
# Epoch 159: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2887 - accuracy: 0.9558 - val_loss: 0.4089 - val_accuracy: 0.9326
# Epoch 160/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9579
# Epoch 160: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2844 - accuracy: 0.9579 - val_loss: 0.4074 - val_accuracy: 0.9328
# Epoch 161/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.9566
# Epoch 161: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2848 - accuracy: 0.9566 - val_loss: 0.4110 - val_accuracy: 0.9322
# Epoch 162/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9573
# Epoch 162: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 128ms/step - loss: 0.2852 - accuracy: 0.9573 - val_loss: 0.4070 - val_accuracy: 0.9317
# Epoch 163/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.9582
# Epoch 163: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 128ms/step - loss: 0.2841 - accuracy: 0.9582 - val_loss: 0.4111 - val_accuracy: 0.9296
# Epoch 164/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.9591
# Epoch 164: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 129ms/step - loss: 0.2811 - accuracy: 0.9591 - val_loss: 0.4040 - val_accuracy: 0.9320
# Epoch 165/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9571
# Epoch 165: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2838 - accuracy: 0.9571 - val_loss: 0.4120 - val_accuracy: 0.9305
# Epoch 166/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.9584
# Epoch 166: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 51s 130ms/step - loss: 0.2820 - accuracy: 0.9584 - val_loss: 0.4065 - val_accuracy: 0.9318
# Epoch 167/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9587
# Epoch 167: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 128ms/step - loss: 0.2788 - accuracy: 0.9587 - val_loss: 0.4062 - val_accuracy: 0.9316
# Epoch 168/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.9589
# Epoch 168: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 50s 128ms/step - loss: 0.2793 - accuracy: 0.9589 - val_loss: 0.4071 - val_accuracy: 0.9309
# Epoch 169/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.9584
# Epoch 169: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 46s 118ms/step - loss: 0.2817 - accuracy: 0.9584 - val_loss: 0.4066 - val_accuracy: 0.9329
# Epoch 170/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9599
# Epoch 170: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2761 - accuracy: 0.9599 - val_loss: 0.4107 - val_accuracy: 0.9324
# Epoch 171/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9596
# Epoch 171: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2781 - accuracy: 0.9596 - val_loss: 0.4145 - val_accuracy: 0.9307
# Epoch 172/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.9595
# Epoch 172: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2770 - accuracy: 0.9595 - val_loss: 0.4083 - val_accuracy: 0.9328
# Epoch 173/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9607
# Epoch 173: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2729 - accuracy: 0.9607 - val_loss: 0.4085 - val_accuracy: 0.9312
# Epoch 174/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9600
# Epoch 174: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2749 - accuracy: 0.9600 - val_loss: 0.4103 - val_accuracy: 0.9317
# Epoch 175/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.9587
# Epoch 175: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 110ms/step - loss: 0.2777 - accuracy: 0.9587 - val_loss: 0.4070 - val_accuracy: 0.9323
# Epoch 176/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9590
# Epoch 176: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2778 - accuracy: 0.9590 - val_loss: 0.4099 - val_accuracy: 0.9313
# Epoch 177/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9605
# Epoch 177: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2739 - accuracy: 0.9605 - val_loss: 0.4100 - val_accuracy: 0.9314
# Epoch 178/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9595
# Epoch 178: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2728 - accuracy: 0.9595 - val_loss: 0.4115 - val_accuracy: 0.9317
# Epoch 179/182
# 389/390 [============================>.] - ETA: 0s - loss: 0.2703 - accuracy: 0.9614
# Epoch 179: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 110ms/step - loss: 0.2702 - accuracy: 0.9615 - val_loss: 0.4090 - val_accuracy: 0.9322
# Epoch 180/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.9596
# Epoch 180: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2743 - accuracy: 0.9596 - val_loss: 0.4107 - val_accuracy: 0.9311
# Epoch 181/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9606
# Epoch 181: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2714 - accuracy: 0.9606 - val_loss: 0.4049 - val_accuracy: 0.9316
# Epoch 182/182
# 390/390 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9623
# Epoch 182: val_loss did not improve from 0.40333
# lr:1.00e-03
# 390/390 [==============================] - 43s 111ms/step - loss: 0.2682 - accuracy: 0.9623 - val_loss: 0.4054 - val_accuracy: 0.9322

# %% [markdown]
# ## 6. Show transition of accuracy

# %%
# import matplotlib.pyplot as plt

# plt.plot(history.history["accuracy"], label = 'Train Accuracy')
# plt.plot(history.history["val_accuracy"], linestyle = 'dashed', label = 'Test Accuracy')
# plt.legend()
# plt.show()

# %%
model.evaluate(test_x, test_y)
# Out:
# 313/313 [==============================] - 9s 28ms/step - loss: 0.4057 - accuracy: 0.9321
# [0.4057457745075226, 0.9320999979972839]
