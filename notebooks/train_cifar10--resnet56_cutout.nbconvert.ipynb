# %%
# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb

# %%
import os
import sys
import git
import pathlib

import random

import numpy as np
import tensorflow as tf
from tensorflow import keras

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

from libs.constants import MODELS_FOLDER

# %%
# Limit GPU growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
import libs.model_archs
import libs.utils
from libs.seeds import load_model_seeds
model_seeds = load_model_seeds()

# %%
# define dataset and model architecture
dataset = "cifar10"
# Select ResNet Version
resnet_version = 1
model_arch = "resnetA" + str(resnet_version)

# set training hyperparameters
batch_size = 128
n_epochs = 200

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()
# ZCA whiteningなどを行う場合が以下の実行が必要
# datagen.fit(train_x)
# datagen_for_test.fit(test_x)

# %%
# global seed
seed = model_seeds[0]
tf.random.set_seed(seed)
np.random.seed(seed)

# prepare data
# dataset_loader = getattr(libs.utils, 'prepare_'+dataset)
# to_categorical=False
# (x_train, y_train), (x_test, y_test) = dataset_loader(to_categorical)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

dataset_test = (x_test, y_test) 
dataset_train = (x_train, y_train)

x_train = dataset_train[0] / 255
y_train = dataset_train[1].squeeze()
x_test = dataset_test[0] / 255
y_test = dataset_test[1].squeeze()

number_train = x_train.shape[0]
number_test = x_test.shape[0]

# %%
# from tensorflow.keras.callbacks import Callback
# class LearningController(Callback):
#     def __init__(self, num_epoch=0, learn_minute=0):
#         self.num_epoch = num_epoch
#         self.learn_second = learn_minute * 60
#         if self.learn_second > 0:
#             print("Learning rate is controled by time.")
#         elif self.num_epoch > 0:
#             print("Learning rate is controled by epoch.")
        
#     def on_train_begin(self, logs=None):
#         if self.learn_second > 0:
#             self.start_time = time.time()

#     def on_epoch_end(self, epoch, logs=None):
#         if self.learn_second > 0:
#             current_time = time.time()
#             if current_time - self.start_time > self.learn_second:
#                 self.model.stop_training = True
#                 print("Time is up.")
#                 return

#             if current_time - self.start_time > self.learn_second / 2:
#                 self.model.optimizer.lr = lr * 0.1            
#             if current_time - self.start_time > self.learn_second * 3 / 4:
#                 self.model.optimizer.lr = lr * 0.01
                
#         elif self.num_epoch > 0:
#             if epoch > self.num_epoch / 2:
#                 self.model.optimizer.lr = lr * 0.1            
#             if epoch > self.num_epoch * 3 / 4:
#                 self.model.optimizer.lr = lr * 0.01
                    
#         print('\nlr:%.2e' % self.model.optimizer.lr.value())

# %%
# create model
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2


input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
n_classes = y_train.shape

# n_channels = x_train.shape[3] # no. of channels (?)
# # Computed depth of model
# if resnet_version == 1:
# 	depth = n_channels * 6 + 2
# elif resnet_version == 2:
# 	depth = n_channels * 9 + 2

# model_generator = getattr(libs.model_archs, model_arch)
# model = model_generator(input_shape, depth, n_classes)

# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb
n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=input_shape)
x = Conv2D(channels[0], 
           kernel_size=(3, 3), 
           padding="same", 
           kernel_initializer="he_normal", 
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   strides=strides, 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if subsampling:
            x = Conv2D(c, 
                       kernel_size=(1, 1), 
                       strides=(2, 2), 
                       padding="same", 
                       kernel_initializer="he_normal", 
                       kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, 
                activation=tf.nn.softmax, 
                kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)

model._name = "resnet_lrs_cutout" + str(6 * n + 2)

# %%
# from tensorflow.keras.callbacks import ModelCheckpoint
# checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", 
#                              monitor="val_loss", 
#                              verbose=1, 
#                              save_best_only=True)

# %%
# compile model
from tensorflow.keras.optimizers import SGD
# model.compile(loss ='categorical_crossentropy',
#               optimizer ='adam',
#               metrics =['accuracy'])
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, 
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"])

# learning_controller = LearningController(n_epochs)
# callbacks = [learning_controller]
# train model
model.fit(datagen.flow(x_train, 
                         y_train, 
                         batch_size=batch_size), 
          epochs=n_epochs,
          steps_per_epoch=number_train//batch_size,
          validation_data=datagen_for_test.flow(x_test, 
                                                  y_test, 
                                                  batch_size=batch_size),
          validation_steps=number_test//batch_size,
          validation_split=0.2,
          # callbacks=callbacks
         )
# Out:
# Epoch 1/200
# 390/390 [==============================] - 49s 82ms/step - loss: 3.0857 - accuracy: 0.0995 - val_loss: 2.8261 - val_accuracy: 0.1002
# Epoch 2/200
# 390/390 [==============================] - 31s 79ms/step - loss: 2.7876 - accuracy: 0.1011 - val_loss: 2.7492 - val_accuracy: 0.1040
# Epoch 3/200
# 390/390 [==============================] - 31s 78ms/step - loss: 2.7011 - accuracy: 0.1140 - val_loss: 2.5926 - val_accuracy: 0.1655
# Epoch 4/200
# 390/390 [==============================] - 31s 79ms/step - loss: 2.4433 - accuracy: 0.1964 - val_loss: 2.5233 - val_accuracy: 0.1693
# Epoch 5/200
# 390/390 [==============================] - 31s 79ms/step - loss: 2.1853 - accuracy: 0.2907 - val_loss: 2.4838 - val_accuracy: 0.2414
# Epoch 6/200
# 390/390 [==============================] - 31s 78ms/step - loss: 1.9764 - accuracy: 0.3546 - val_loss: 2.0643 - val_accuracy: 0.3352
# Epoch 7/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.8367 - accuracy: 0.4071 - val_loss: 2.0378 - val_accuracy: 0.3869
# Epoch 8/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.7072 - accuracy: 0.4510 - val_loss: 1.6030 - val_accuracy: 0.4960
# Epoch 9/200
# 390/390 [==============================] - 31s 78ms/step - loss: 1.6030 - accuracy: 0.4894 - val_loss: 1.7634 - val_accuracy: 0.4546
# Epoch 10/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.5018 - accuracy: 0.5248 - val_loss: 2.0735 - val_accuracy: 0.4233
# Epoch 11/200
# 390/390 [==============================] - 30s 78ms/step - loss: 1.4203 - accuracy: 0.5540 - val_loss: 1.6422 - val_accuracy: 0.4736
# Epoch 12/200
# 390/390 [==============================] - 30s 78ms/step - loss: 1.3343 - accuracy: 0.5832 - val_loss: 1.6024 - val_accuracy: 0.5369
# Epoch 13/200
# 390/390 [==============================] - 31s 78ms/step - loss: 1.2660 - accuracy: 0.6083 - val_loss: 1.7922 - val_accuracy: 0.4960
# Epoch 14/200
# 390/390 [==============================] - 31s 78ms/step - loss: 1.2044 - accuracy: 0.6319 - val_loss: 1.4882 - val_accuracy: 0.5894
# Epoch 15/200
# 390/390 [==============================] - 31s 78ms/step - loss: 1.1578 - accuracy: 0.6501 - val_loss: 1.2262 - val_accuracy: 0.6448
# Epoch 16/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.1345 - accuracy: 0.6572 - val_loss: 2.0792 - val_accuracy: 0.4536
# Epoch 17/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.1000 - accuracy: 0.6731 - val_loss: 1.2132 - val_accuracy: 0.6466
# Epoch 18/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0745 - accuracy: 0.6827 - val_loss: 1.1645 - val_accuracy: 0.6830
# Epoch 19/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0351 - accuracy: 0.6975 - val_loss: 1.4690 - val_accuracy: 0.6057
# Epoch 20/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0106 - accuracy: 0.7042 - val_loss: 2.2636 - val_accuracy: 0.4727
# Epoch 21/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9913 - accuracy: 0.7126 - val_loss: 1.4216 - val_accuracy: 0.6285
# Epoch 22/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9826 - accuracy: 0.7134 - val_loss: 1.9534 - val_accuracy: 0.5097
# Epoch 23/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9622 - accuracy: 0.7262 - val_loss: 0.9844 - val_accuracy: 0.7299
# Epoch 24/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.9497 - accuracy: 0.7288 - val_loss: 1.5072 - val_accuracy: 0.6018
# Epoch 25/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9369 - accuracy: 0.7368 - val_loss: 1.3058 - val_accuracy: 0.6806
# Epoch 26/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9366 - accuracy: 0.7358 - val_loss: 1.0253 - val_accuracy: 0.7252
# Epoch 27/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.9138 - accuracy: 0.7443 - val_loss: 1.0812 - val_accuracy: 0.6985
# Epoch 28/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.9071 - accuracy: 0.7482 - val_loss: 1.0812 - val_accuracy: 0.7051
# Epoch 29/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8901 - accuracy: 0.7543 - val_loss: 1.6643 - val_accuracy: 0.5738
# Epoch 30/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8840 - accuracy: 0.7569 - val_loss: 1.0419 - val_accuracy: 0.7231
# Epoch 31/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8860 - accuracy: 0.7589 - val_loss: 1.0172 - val_accuracy: 0.7291
# Epoch 32/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8754 - accuracy: 0.7642 - val_loss: 1.4199 - val_accuracy: 0.6205
# Epoch 33/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8692 - accuracy: 0.7655 - val_loss: 0.8814 - val_accuracy: 0.7680
# Epoch 34/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8566 - accuracy: 0.7711 - val_loss: 0.8625 - val_accuracy: 0.7766
# Epoch 35/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8575 - accuracy: 0.7723 - val_loss: 0.9196 - val_accuracy: 0.7683
# Epoch 36/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8472 - accuracy: 0.7752 - val_loss: 1.2093 - val_accuracy: 0.6771
# Epoch 37/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8417 - accuracy: 0.7802 - val_loss: 1.1279 - val_accuracy: 0.7203
# Epoch 38/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8362 - accuracy: 0.7812 - val_loss: 1.0630 - val_accuracy: 0.7286
# Epoch 39/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8358 - accuracy: 0.7814 - val_loss: 1.0234 - val_accuracy: 0.7505
# Epoch 40/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8309 - accuracy: 0.7826 - val_loss: 1.1172 - val_accuracy: 0.7256
# Epoch 41/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8266 - accuracy: 0.7878 - val_loss: 1.3241 - val_accuracy: 0.6661
# Epoch 42/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8262 - accuracy: 0.7875 - val_loss: 0.8459 - val_accuracy: 0.7882
# Epoch 43/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8204 - accuracy: 0.7893 - val_loss: 1.4270 - val_accuracy: 0.6516
# Epoch 44/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8166 - accuracy: 0.7906 - val_loss: 1.0520 - val_accuracy: 0.7485
# Epoch 45/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8155 - accuracy: 0.7936 - val_loss: 0.9257 - val_accuracy: 0.7613
# Epoch 46/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8130 - accuracy: 0.7930 - val_loss: 1.1682 - val_accuracy: 0.6876
# Epoch 47/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8060 - accuracy: 0.7961 - val_loss: 1.0259 - val_accuracy: 0.7654
# Epoch 48/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8138 - accuracy: 0.7941 - val_loss: 1.3314 - val_accuracy: 0.6710
# Epoch 49/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.8071 - accuracy: 0.7961 - val_loss: 0.7660 - val_accuracy: 0.8156
# Epoch 50/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7945 - accuracy: 0.8036 - val_loss: 0.9570 - val_accuracy: 0.7799
# Epoch 51/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7978 - accuracy: 0.8015 - val_loss: 1.2049 - val_accuracy: 0.7267
# Epoch 52/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7985 - accuracy: 0.8012 - val_loss: 1.2644 - val_accuracy: 0.6891
# Epoch 53/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7991 - accuracy: 0.8023 - val_loss: 1.1990 - val_accuracy: 0.7123
# Epoch 54/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7967 - accuracy: 0.8019 - val_loss: 1.0639 - val_accuracy: 0.7352
# Epoch 55/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7882 - accuracy: 0.8070 - val_loss: 1.0480 - val_accuracy: 0.7426
# Epoch 56/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7888 - accuracy: 0.8069 - val_loss: 0.7372 - val_accuracy: 0.8319
# Epoch 57/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7887 - accuracy: 0.8068 - val_loss: 1.0677 - val_accuracy: 0.7241
# Epoch 58/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7817 - accuracy: 0.8103 - val_loss: 1.0013 - val_accuracy: 0.7538
# Epoch 59/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7811 - accuracy: 0.8114 - val_loss: 1.0375 - val_accuracy: 0.7540
# Epoch 60/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7755 - accuracy: 0.8122 - val_loss: 1.3005 - val_accuracy: 0.6945
# Epoch 61/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7813 - accuracy: 0.8129 - val_loss: 0.9797 - val_accuracy: 0.7684
# Epoch 62/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7801 - accuracy: 0.8128 - val_loss: 0.8281 - val_accuracy: 0.8062
# Epoch 63/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7725 - accuracy: 0.8156 - val_loss: 0.8262 - val_accuracy: 0.8132
# Epoch 64/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7817 - accuracy: 0.8115 - val_loss: 1.0951 - val_accuracy: 0.7424
# Epoch 65/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7690 - accuracy: 0.8172 - val_loss: 1.1808 - val_accuracy: 0.7249
# Epoch 66/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7689 - accuracy: 0.8165 - val_loss: 1.0973 - val_accuracy: 0.7446
# Epoch 67/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7696 - accuracy: 0.8178 - val_loss: 1.2582 - val_accuracy: 0.7302
# Epoch 68/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7684 - accuracy: 0.8185 - val_loss: 0.8275 - val_accuracy: 0.8060
# Epoch 69/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7647 - accuracy: 0.8196 - val_loss: 1.2747 - val_accuracy: 0.6975
# Epoch 70/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7714 - accuracy: 0.8192 - val_loss: 1.1541 - val_accuracy: 0.7156
# Epoch 71/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7623 - accuracy: 0.8206 - val_loss: 0.9306 - val_accuracy: 0.7877
# Epoch 72/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.7600 - accuracy: 0.8244 - val_loss: 1.0665 - val_accuracy: 0.7427
# Epoch 73/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7569 - accuracy: 0.8232 - val_loss: 0.9045 - val_accuracy: 0.7941
# Epoch 74/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7578 - accuracy: 0.8222 - val_loss: 0.7980 - val_accuracy: 0.8204
# Epoch 75/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7565 - accuracy: 0.8240 - val_loss: 1.1429 - val_accuracy: 0.7402
# Epoch 76/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7601 - accuracy: 0.8222 - val_loss: 1.0071 - val_accuracy: 0.7743
# Epoch 77/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7494 - accuracy: 0.8287 - val_loss: 0.8637 - val_accuracy: 0.7984
# Epoch 78/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7550 - accuracy: 0.8255 - val_loss: 1.9738 - val_accuracy: 0.6167
# Epoch 79/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7513 - accuracy: 0.8268 - val_loss: 0.7583 - val_accuracy: 0.8342
# Epoch 80/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7576 - accuracy: 0.8256 - val_loss: 0.9791 - val_accuracy: 0.7820
# Epoch 81/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7469 - accuracy: 0.8276 - val_loss: 1.3806 - val_accuracy: 0.6879
# Epoch 82/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7518 - accuracy: 0.8260 - val_loss: 1.0020 - val_accuracy: 0.7742
# Epoch 83/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7444 - accuracy: 0.8301 - val_loss: 0.9571 - val_accuracy: 0.7736
# Epoch 84/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7455 - accuracy: 0.8291 - val_loss: 0.9476 - val_accuracy: 0.7992
# Epoch 85/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7477 - accuracy: 0.8305 - val_loss: 0.8031 - val_accuracy: 0.8154
# Epoch 86/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7431 - accuracy: 0.8298 - val_loss: 0.7430 - val_accuracy: 0.8413
# Epoch 87/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7475 - accuracy: 0.8277 - val_loss: 1.0416 - val_accuracy: 0.7687
# Epoch 88/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7473 - accuracy: 0.8304 - val_loss: 0.8929 - val_accuracy: 0.7959
# Epoch 89/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7424 - accuracy: 0.8303 - val_loss: 0.7468 - val_accuracy: 0.8424
# Epoch 90/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7389 - accuracy: 0.8346 - val_loss: 0.8501 - val_accuracy: 0.8185
# Epoch 91/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7419 - accuracy: 0.8310 - val_loss: 0.8563 - val_accuracy: 0.8091
# Epoch 92/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7348 - accuracy: 0.8331 - val_loss: 0.8971 - val_accuracy: 0.8022
# Epoch 93/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7455 - accuracy: 0.8305 - val_loss: 0.9218 - val_accuracy: 0.7882
# Epoch 94/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7343 - accuracy: 0.8371 - val_loss: 0.8724 - val_accuracy: 0.8027
# Epoch 95/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.7406 - accuracy: 0.8346 - val_loss: 0.9603 - val_accuracy: 0.7873
# Epoch 96/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7342 - accuracy: 0.8375 - val_loss: 0.7585 - val_accuracy: 0.8449
# Epoch 97/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7358 - accuracy: 0.8339 - val_loss: 1.3630 - val_accuracy: 0.7083
# Epoch 98/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7410 - accuracy: 0.8359 - val_loss: 0.9634 - val_accuracy: 0.7784
# Epoch 99/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7322 - accuracy: 0.8383 - val_loss: 0.9803 - val_accuracy: 0.7744
# Epoch 100/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7348 - accuracy: 0.8361 - val_loss: 0.8912 - val_accuracy: 0.8039
# Epoch 101/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7325 - accuracy: 0.8385 - val_loss: 0.8453 - val_accuracy: 0.8094
# Epoch 102/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7346 - accuracy: 0.8357 - val_loss: 0.9406 - val_accuracy: 0.7868
# Epoch 103/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7267 - accuracy: 0.8403 - val_loss: 0.8264 - val_accuracy: 0.8164
# Epoch 104/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7327 - accuracy: 0.8391 - val_loss: 0.8388 - val_accuracy: 0.8153
# Epoch 105/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7279 - accuracy: 0.8391 - val_loss: 0.9301 - val_accuracy: 0.8027
# Epoch 106/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7306 - accuracy: 0.8365 - val_loss: 1.2279 - val_accuracy: 0.7325
# Epoch 107/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7300 - accuracy: 0.8384 - val_loss: 0.8427 - val_accuracy: 0.8125
# Epoch 108/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7322 - accuracy: 0.8385 - val_loss: 1.3860 - val_accuracy: 0.7249
# Epoch 109/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7226 - accuracy: 0.8420 - val_loss: 0.8544 - val_accuracy: 0.8052
# Epoch 110/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.7143 - accuracy: 0.8438 - val_loss: 0.8212 - val_accuracy: 0.8261
# Epoch 111/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7270 - accuracy: 0.8412 - val_loss: 0.9076 - val_accuracy: 0.7942
# Epoch 112/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7186 - accuracy: 0.8435 - val_loss: 0.8203 - val_accuracy: 0.8279
# Epoch 113/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7265 - accuracy: 0.8416 - val_loss: 1.1623 - val_accuracy: 0.7380
# Epoch 114/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7240 - accuracy: 0.8422 - val_loss: 0.8628 - val_accuracy: 0.8078
# Epoch 115/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7280 - accuracy: 0.8416 - val_loss: 0.7201 - val_accuracy: 0.8549
# Epoch 116/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7214 - accuracy: 0.8436 - val_loss: 0.9870 - val_accuracy: 0.7870
# Epoch 117/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7179 - accuracy: 0.8441 - val_loss: 0.7917 - val_accuracy: 0.8370
# Epoch 118/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7229 - accuracy: 0.8419 - val_loss: 0.7067 - val_accuracy: 0.8583
# Epoch 119/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7175 - accuracy: 0.8447 - val_loss: 0.7857 - val_accuracy: 0.8286
# Epoch 120/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7218 - accuracy: 0.8430 - val_loss: 0.7810 - val_accuracy: 0.8346
# Epoch 121/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7192 - accuracy: 0.8434 - val_loss: 0.8416 - val_accuracy: 0.8203
# Epoch 122/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7242 - accuracy: 0.8425 - val_loss: 0.8349 - val_accuracy: 0.8226
# Epoch 123/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7256 - accuracy: 0.8435 - val_loss: 0.7480 - val_accuracy: 0.8455
# Epoch 124/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7098 - accuracy: 0.8483 - val_loss: 0.8492 - val_accuracy: 0.8204
# Epoch 125/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7164 - accuracy: 0.8453 - val_loss: 0.7978 - val_accuracy: 0.8233
# Epoch 126/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7265 - accuracy: 0.8436 - val_loss: 1.1856 - val_accuracy: 0.7457
# Epoch 127/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7245 - accuracy: 0.8443 - val_loss: 0.9299 - val_accuracy: 0.7978
# Epoch 128/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7145 - accuracy: 0.8476 - val_loss: 1.8459 - val_accuracy: 0.6311
# Epoch 129/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7159 - accuracy: 0.8475 - val_loss: 0.7746 - val_accuracy: 0.8413
# Epoch 130/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7060 - accuracy: 0.8499 - val_loss: 0.8491 - val_accuracy: 0.8164
# Epoch 131/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7161 - accuracy: 0.8466 - val_loss: 0.7784 - val_accuracy: 0.8358
# Epoch 132/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7145 - accuracy: 0.8462 - val_loss: 1.0725 - val_accuracy: 0.7701
# Epoch 133/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7172 - accuracy: 0.8459 - val_loss: 0.7126 - val_accuracy: 0.8557
# Epoch 134/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7133 - accuracy: 0.8476 - val_loss: 0.9929 - val_accuracy: 0.7689
# Epoch 135/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7137 - accuracy: 0.8476 - val_loss: 1.2224 - val_accuracy: 0.7461
# Epoch 136/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7119 - accuracy: 0.8471 - val_loss: 0.9548 - val_accuracy: 0.7913
# Epoch 137/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7133 - accuracy: 0.8491 - val_loss: 1.0023 - val_accuracy: 0.7731
# Epoch 138/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7142 - accuracy: 0.8484 - val_loss: 0.8122 - val_accuracy: 0.8314
# Epoch 139/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7087 - accuracy: 0.8496 - val_loss: 0.9754 - val_accuracy: 0.7801
# Epoch 140/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7064 - accuracy: 0.8511 - val_loss: 0.8373 - val_accuracy: 0.8111
# Epoch 141/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7096 - accuracy: 0.8503 - val_loss: 0.7293 - val_accuracy: 0.8559
# Epoch 142/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7075 - accuracy: 0.8510 - val_loss: 1.0890 - val_accuracy: 0.7714
# Epoch 143/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7137 - accuracy: 0.8498 - val_loss: 0.8219 - val_accuracy: 0.8345
# Epoch 144/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7110 - accuracy: 0.8498 - val_loss: 0.8103 - val_accuracy: 0.8230
# Epoch 145/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7061 - accuracy: 0.8526 - val_loss: 1.2521 - val_accuracy: 0.7273
# Epoch 146/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7142 - accuracy: 0.8489 - val_loss: 0.7531 - val_accuracy: 0.8508
# Epoch 147/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.7076 - accuracy: 0.8512 - val_loss: 0.8473 - val_accuracy: 0.8186
# Epoch 148/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7041 - accuracy: 0.8517 - val_loss: 1.2409 - val_accuracy: 0.7290
# Epoch 149/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7125 - accuracy: 0.8502 - val_loss: 0.9813 - val_accuracy: 0.7845
# Epoch 150/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7074 - accuracy: 0.8517 - val_loss: 0.8261 - val_accuracy: 0.8244
# Epoch 151/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7056 - accuracy: 0.8528 - val_loss: 0.9435 - val_accuracy: 0.8024
# Epoch 152/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7042 - accuracy: 0.8535 - val_loss: 0.9416 - val_accuracy: 0.7915
# Epoch 153/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7073 - accuracy: 0.8517 - val_loss: 0.8186 - val_accuracy: 0.8336
# Epoch 154/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7055 - accuracy: 0.8540 - val_loss: 0.8055 - val_accuracy: 0.8391
# Epoch 155/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7112 - accuracy: 0.8504 - val_loss: 0.8897 - val_accuracy: 0.8097
# Epoch 156/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7088 - accuracy: 0.8525 - val_loss: 0.7793 - val_accuracy: 0.8368
# Epoch 157/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7011 - accuracy: 0.8557 - val_loss: 1.2585 - val_accuracy: 0.7405
# Epoch 158/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7062 - accuracy: 0.8551 - val_loss: 0.9127 - val_accuracy: 0.8008
# Epoch 159/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7040 - accuracy: 0.8540 - val_loss: 0.9663 - val_accuracy: 0.7854
# Epoch 160/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7032 - accuracy: 0.8545 - val_loss: 1.0545 - val_accuracy: 0.7739
# Epoch 161/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7014 - accuracy: 0.8541 - val_loss: 0.8979 - val_accuracy: 0.8110
# Epoch 162/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7051 - accuracy: 0.8538 - val_loss: 1.0564 - val_accuracy: 0.7779
# Epoch 163/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.6994 - accuracy: 0.8553 - val_loss: 0.8118 - val_accuracy: 0.8227
# Epoch 164/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7003 - accuracy: 0.8539 - val_loss: 0.7994 - val_accuracy: 0.8377
# Epoch 165/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7038 - accuracy: 0.8534 - val_loss: 0.7276 - val_accuracy: 0.8570
# Epoch 166/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7016 - accuracy: 0.8537 - val_loss: 0.7372 - val_accuracy: 0.8466
# Epoch 167/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7031 - accuracy: 0.8553 - val_loss: 0.7022 - val_accuracy: 0.8642
# Epoch 168/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7046 - accuracy: 0.8546 - val_loss: 1.2111 - val_accuracy: 0.7408
# Epoch 169/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7043 - accuracy: 0.8570 - val_loss: 0.8470 - val_accuracy: 0.8325
# Epoch 170/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6965 - accuracy: 0.8551 - val_loss: 0.7792 - val_accuracy: 0.8468
# Epoch 171/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7022 - accuracy: 0.8564 - val_loss: 0.9172 - val_accuracy: 0.8071
# Epoch 172/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7033 - accuracy: 0.8555 - val_loss: 1.0714 - val_accuracy: 0.7608
# Epoch 173/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.6954 - accuracy: 0.8578 - val_loss: 0.7993 - val_accuracy: 0.8402
# Epoch 174/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.6986 - accuracy: 0.8564 - val_loss: 1.0925 - val_accuracy: 0.7578
# Epoch 175/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6966 - accuracy: 0.8588 - val_loss: 0.7836 - val_accuracy: 0.8436
# Epoch 176/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.7043 - accuracy: 0.8572 - val_loss: 0.8821 - val_accuracy: 0.8050
# Epoch 177/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6954 - accuracy: 0.8583 - val_loss: 0.7225 - val_accuracy: 0.8574
# Epoch 178/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.6941 - accuracy: 0.8580 - val_loss: 0.9561 - val_accuracy: 0.7978
# Epoch 179/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.6981 - accuracy: 0.8565 - val_loss: 0.7364 - val_accuracy: 0.8545
# Epoch 180/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7013 - accuracy: 0.8571 - val_loss: 0.9664 - val_accuracy: 0.7966
# Epoch 181/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6933 - accuracy: 0.8591 - val_loss: 1.3279 - val_accuracy: 0.7009
# Epoch 182/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.6957 - accuracy: 0.8580 - val_loss: 0.8481 - val_accuracy: 0.8195
# Epoch 183/200
# 390/390 [==============================] - 23s 60ms/step - loss: 0.6944 - accuracy: 0.8602 - val_loss: 0.7653 - val_accuracy: 0.8427
# Epoch 184/200
# 390/390 [==============================] - 22s 56ms/step - loss: 0.7004 - accuracy: 0.8566 - val_loss: 0.8673 - val_accuracy: 0.8188
# Epoch 185/200
# 390/390 [==============================] - 21s 54ms/step - loss: 0.6992 - accuracy: 0.8577 - val_loss: 0.9013 - val_accuracy: 0.8239
# Epoch 186/200
# 390/390 [==============================] - 21s 54ms/step - loss: 0.6930 - accuracy: 0.8593 - val_loss: 0.6972 - val_accuracy: 0.8718
# Epoch 187/200
# 390/390 [==============================] - 21s 54ms/step - loss: 0.7016 - accuracy: 0.8566 - val_loss: 0.8145 - val_accuracy: 0.8412
# Epoch 188/200
# 390/390 [==============================] - 22s 55ms/step - loss: 0.6940 - accuracy: 0.8586 - val_loss: 0.8775 - val_accuracy: 0.8059
# Epoch 189/200
# 390/390 [==============================] - 21s 53ms/step - loss: 0.6996 - accuracy: 0.8575 - val_loss: 1.3156 - val_accuracy: 0.7310
# Epoch 190/200
# 390/390 [==============================] - 21s 54ms/step - loss: 0.6963 - accuracy: 0.8577 - val_loss: 0.8434 - val_accuracy: 0.8249
# Epoch 191/200
# 390/390 [==============================] - 21s 54ms/step - loss: 0.6937 - accuracy: 0.8583 - val_loss: 0.9181 - val_accuracy: 0.8053
# Epoch 192/200
# 390/390 [==============================] - 22s 55ms/step - loss: 0.6943 - accuracy: 0.8593 - val_loss: 0.8871 - val_accuracy: 0.8157
# Epoch 193/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6945 - accuracy: 0.8611 - val_loss: 0.7993 - val_accuracy: 0.8343
# Epoch 194/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6964 - accuracy: 0.8589 - val_loss: 0.7910 - val_accuracy: 0.8459
# Epoch 195/200
# 390/390 [==============================] - 23s 60ms/step - loss: 0.6961 - accuracy: 0.8586 - val_loss: 0.9677 - val_accuracy: 0.7981
# Epoch 196/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6925 - accuracy: 0.8600 - val_loss: 0.7819 - val_accuracy: 0.8443
# Epoch 197/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6948 - accuracy: 0.8568 - val_loss: 1.2602 - val_accuracy: 0.7015
# Epoch 198/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6930 - accuracy: 0.8605 - val_loss: 1.0055 - val_accuracy: 0.7873
# Epoch 199/200
# 390/390 [==============================] - 23s 59ms/step - loss: 0.6988 - accuracy: 0.8588 - val_loss: 0.7994 - val_accuracy: 0.8447
# Epoch 200/200
# 390/390 [==============================] - 23s 58ms/step - loss: 0.6941 - accuracy: 0.8596 - val_loss: 0.7304 - val_accuracy: 0.8515

# %%
# evaluate model
score = model.evaluate(x_test, 
                       y_test, 
                       batch_size=batch_size)

print("Original Accuracy: ",score)
# Out:
# 79/79 [==============================] - 1s 17ms/step - loss: 0.7303 - accuracy: 0.8514
# Original Accuracy:  [0.730278730392456, 0.8514000177383423]

# %%
# save model
model_type = dataset + "--" + model_arch
model_instance = model_type + "-" + str(seed)
model_filename = model_instance + ".h5"
model_subdir = pathlib.Path(MODELS_FOLDER / model.name)
pathlib.Path(model_subdir).mkdir(parents=True, exist_ok=True)
model_file = str(pathlib.Path(model_subdir/ model_filename))
model.save(model_file)

# %%
model.summary()
# Out:
# Model: "resnet_lrs_cutout56"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_12[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 16)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['add_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   544         ['activation_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['conv2d_21[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 32)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 32)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 32)   0           ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['activation_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_28[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 16, 16, 32)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['add_15[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 16, 16, 32)   0           ['activation_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_34 (Activation)     (None, 16, 16, 32)   0           ['add_16[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 16, 16, 32)   0           ['activation_34[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 32)   0           ['add_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 64)     0           ['conv2d_40[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['add_18[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 64)     0           ['activation_38[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['add_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 64)     0           ['activation_40[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['add_20[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 8, 8, 64)     0           ['activation_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['add_21[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 8, 8, 64)     0           ['activation_44[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['add_22[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 8, 8, 64)     0           ['activation_46[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 64)     0           ['add_23[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 64)    256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 8, 8, 64)     0           ['activation_48[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_50 (Activation)     (None, 8, 8, 64)     0           ['add_24[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 64)    256         ['conv2d_54[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 8, 8, 64)     0           ['activation_50[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_52 (Activation)     (None, 8, 8, 64)     0           ['add_25[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 64)    256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 64)    256         ['conv2d_56[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 8, 8, 64)     0           ['activation_52[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  activation_54 (Activation)     (None, 8, 8, 64)     0           ['add_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_54[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 64)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 10)           650         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
