# %%
# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb

# %%
import os
import sys
import git
import pathlib

import random

import numpy as np
import tensorflow as tf
from tensorflow import keras

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

from libs.constants import MODELS_FOLDER

# %%
# Limit GPU growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
import libs.model_archs
import libs.utils
from libs.seeds import load_model_seeds
model_seeds = load_model_seeds()

# %%
# define dataset and model architecture
dataset = "cifar10"
# Select ResNet Version
resnet_version = 1
model_arch = "resnetA" + str(resnet_version)

# set training hyperparameters
batch_size = 128
n_epochs = 200

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()
# ZCA whiteningなどを行う場合が以下の実行が必要
# datagen.fit(train_x)
# datagen_for_test.fit(test_x)

# %%
# global seed
seed = model_seeds[0]
tf.random.set_seed(seed)
np.random.seed(seed)

# prepare data
# dataset_loader = getattr(libs.utils, 'prepare_'+dataset)
# to_categorical=False
# (x_train, y_train), (x_test, y_test) = dataset_loader(to_categorical)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

dataset_test = (x_test, y_test) 
dataset_train = (x_train, y_train)

x_train = dataset_train[0] / 255
y_train = dataset_train[1].squeeze()
x_test = dataset_test[0] / 255
y_test = dataset_test[1].squeeze()

number_train = x_train.shape[0]
number_test = x_test.shape[0]

# %%
from tensorflow.keras.callbacks import Callback
class LearningController(Callback):
    def __init__(self, num_epoch=0, learn_minute=0):
        self.num_epoch = num_epoch
        self.learn_second = learn_minute * 60
        if self.learn_second > 0:
            print("Learning rate is controled by time.")
        elif self.num_epoch > 0:
            print("Learning rate is controled by epoch.")
        
    def on_train_begin(self, logs=None):
        if self.learn_second > 0:
            self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        if self.learn_second > 0:
            current_time = time.time()
            if current_time - self.start_time > self.learn_second:
                self.model.stop_training = True
                print("Time is up.")
                return

            if current_time - self.start_time > self.learn_second / 2:
                self.model.optimizer.lr = lr * 0.1            
            if current_time - self.start_time > self.learn_second * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                
        elif self.num_epoch > 0:
            if epoch > self.num_epoch / 2:
                self.model.optimizer.lr = lr * 0.1            
            if epoch > self.num_epoch * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                    
        print('\nlr:%.2e' % self.model.optimizer.lr.value())

# %%
# create model
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2


input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
n_classes = y_train.shape

# n_channels = x_train.shape[3] # no. of channels (?)
# # Computed depth of model
# if resnet_version == 1:
# 	depth = n_channels * 6 + 2
# elif resnet_version == 2:
# 	depth = n_channels * 9 + 2

# model_generator = getattr(libs.model_archs, model_arch)
# model = model_generator(input_shape, depth, n_classes)

# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb
n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=input_shape)
x = Conv2D(channels[0], 
           kernel_size=(3, 3), 
           padding="same", 
           kernel_initializer="he_normal", 
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   strides=strides, 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if subsampling:
            x = Conv2D(c, 
                       kernel_size=(1, 1), 
                       strides=(2, 2), 
                       padding="same", 
                       kernel_initializer="he_normal", 
                       kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, 
                activation=tf.nn.softmax, 
                kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)

model._name = "resnet_lrs_checkpnt_cutout" + str(6 * n + 2)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", 
                             monitor="val_loss", 
                             verbose=1, 
                             save_best_only=True)

# %%
# compile model
from tensorflow.keras.optimizers import SGD
# model.compile(loss ='categorical_crossentropy',
#               optimizer ='adam',
#               metrics =['accuracy'])
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, 
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"])

learning_controller = LearningController(n_epochs)
callbacks = [checkpoint, learning_controller]
# train model
model.fit(datagen.flow(x_train, 
                         y_train, 
                         batch_size=batch_size), 
          epochs=n_epochs,
          steps_per_epoch=number_train//batch_size,
          validation_data=datagen_for_test.flow(x_test, 
                                                  y_test, 
                                                  batch_size=batch_size),
          validation_steps=number_test//batch_size,
          validation_split=0.2,
          callbacks=callbacks)
# Out:
# Learning rate is controled by epoch.
# Epoch 1/200
# 390/390 [==============================] - ETA: 0s - loss: 3.2654 - accuracy: 0.1150
# Epoch 1: val_loss improved from inf to 2.91118, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 68s 106ms/step - loss: 3.2654 - accuracy: 0.1150 - val_loss: 2.9112 - val_accuracy: 0.1492
# Epoch 2/200
# 390/390 [==============================] - ETA: 0s - loss: 2.6442 - accuracy: 0.2281
# Epoch 2: val_loss did not improve from 2.91118
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 2.6442 - accuracy: 0.2281 - val_loss: 2.9821 - val_accuracy: 0.1978
# Epoch 3/200
# 390/390 [==============================] - ETA: 0s - loss: 2.3322 - accuracy: 0.3251
# Epoch 3: val_loss improved from 2.91118 to 2.34897, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 104ms/step - loss: 2.3322 - accuracy: 0.3251 - val_loss: 2.3490 - val_accuracy: 0.3341
# Epoch 4/200
# 390/390 [==============================] - ETA: 0s - loss: 2.1677 - accuracy: 0.3707
# Epoch 4: val_loss did not improve from 2.34897
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 2.1677 - accuracy: 0.3707 - val_loss: 2.4494 - val_accuracy: 0.3243
# Epoch 5/200
# 390/390 [==============================] - ETA: 0s - loss: 2.0396 - accuracy: 0.3987
# Epoch 5: val_loss improved from 2.34897 to 1.94262, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 2.0396 - accuracy: 0.3987 - val_loss: 1.9426 - val_accuracy: 0.4344
# Epoch 6/200
# 389/390 [============================>.] - ETA: 0s - loss: 1.9453 - accuracy: 0.4145
# Epoch 6: val_loss did not improve from 1.94262
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.9451 - accuracy: 0.4145 - val_loss: 3.4189 - val_accuracy: 0.2697
# Epoch 7/200
# 390/390 [==============================] - ETA: 0s - loss: 1.8738 - accuracy: 0.4292
# Epoch 7: val_loss did not improve from 1.94262
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.8738 - accuracy: 0.4292 - val_loss: 2.0243 - val_accuracy: 0.3863
# Epoch 8/200
# 390/390 [==============================] - ETA: 0s - loss: 1.8078 - accuracy: 0.4371
# Epoch 8: val_loss improved from 1.94262 to 1.82366, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.8078 - accuracy: 0.4371 - val_loss: 1.8237 - val_accuracy: 0.4336
# Epoch 9/200
# 389/390 [============================>.] - ETA: 0s - loss: 1.7490 - accuracy: 0.4515
# Epoch 9: val_loss did not improve from 1.82366
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.7487 - accuracy: 0.4516 - val_loss: 1.9628 - val_accuracy: 0.4268
# Epoch 10/200
# 390/390 [==============================] - ETA: 0s - loss: 1.6757 - accuracy: 0.4693
# Epoch 10: val_loss did not improve from 1.82366
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.6757 - accuracy: 0.4693 - val_loss: 3.1518 - val_accuracy: 0.2650
# Epoch 11/200
# 390/390 [==============================] - ETA: 0s - loss: 1.6030 - accuracy: 0.4906
# Epoch 11: val_loss did not improve from 1.82366
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.6030 - accuracy: 0.4906 - val_loss: 2.2164 - val_accuracy: 0.3902
# Epoch 12/200
# 390/390 [==============================] - ETA: 0s - loss: 1.5211 - accuracy: 0.5175
# Epoch 12: val_loss improved from 1.82366 to 1.36491, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.5211 - accuracy: 0.5175 - val_loss: 1.3649 - val_accuracy: 0.5695
# Epoch 13/200
# 390/390 [==============================] - ETA: 0s - loss: 1.4601 - accuracy: 0.5379
# Epoch 13: val_loss did not improve from 1.36491
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.4601 - accuracy: 0.5379 - val_loss: 2.5431 - val_accuracy: 0.3725
# Epoch 14/200
# 390/390 [==============================] - ETA: 0s - loss: 1.4052 - accuracy: 0.5589
# Epoch 14: val_loss did not improve from 1.36491
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.4052 - accuracy: 0.5589 - val_loss: 1.8947 - val_accuracy: 0.4431
# Epoch 15/200
# 390/390 [==============================] - ETA: 0s - loss: 1.3618 - accuracy: 0.5724
# Epoch 15: val_loss did not improve from 1.36491
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.3618 - accuracy: 0.5724 - val_loss: 1.6549 - val_accuracy: 0.5181
# Epoch 16/200
# 390/390 [==============================] - ETA: 0s - loss: 1.3061 - accuracy: 0.5952
# Epoch 16: val_loss did not improve from 1.36491
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.3061 - accuracy: 0.5952 - val_loss: 1.4103 - val_accuracy: 0.5894
# Epoch 17/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2632 - accuracy: 0.6109
# Epoch 17: val_loss improved from 1.36491 to 1.34977, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.2632 - accuracy: 0.6109 - val_loss: 1.3498 - val_accuracy: 0.5944
# Epoch 18/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2396 - accuracy: 0.6189
# Epoch 18: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.2396 - accuracy: 0.6189 - val_loss: 2.4699 - val_accuracy: 0.4017
# Epoch 19/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2108 - accuracy: 0.6324
# Epoch 19: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 1.2108 - accuracy: 0.6324 - val_loss: 2.1658 - val_accuracy: 0.4735
# Epoch 20/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1844 - accuracy: 0.6397
# Epoch 20: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.1844 - accuracy: 0.6397 - val_loss: 1.7747 - val_accuracy: 0.5232
# Epoch 21/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1687 - accuracy: 0.6490
# Epoch 21: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 1.1687 - accuracy: 0.6490 - val_loss: 1.4275 - val_accuracy: 0.5959
# Epoch 22/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1478 - accuracy: 0.6576
# Epoch 22: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.1478 - accuracy: 0.6576 - val_loss: 2.3453 - val_accuracy: 0.4965
# Epoch 23/200
# 389/390 [============================>.] - ETA: 0s - loss: 1.1157 - accuracy: 0.6689
# Epoch 23: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.1163 - accuracy: 0.6687 - val_loss: 1.4824 - val_accuracy: 0.5942
# Epoch 24/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1020 - accuracy: 0.6749
# Epoch 24: val_loss did not improve from 1.34977
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.1020 - accuracy: 0.6749 - val_loss: 1.7134 - val_accuracy: 0.5593
# Epoch 25/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.6772
# Epoch 25: val_loss improved from 1.34977 to 1.19507, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.0983 - accuracy: 0.6772 - val_loss: 1.1951 - val_accuracy: 0.6685
# Epoch 26/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0748 - accuracy: 0.6895
# Epoch 26: val_loss improved from 1.19507 to 1.05862, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 104ms/step - loss: 1.0748 - accuracy: 0.6895 - val_loss: 1.0586 - val_accuracy: 0.7077
# Epoch 27/200
# 389/390 [============================>.] - ETA: 0s - loss: 1.0575 - accuracy: 0.6956
# Epoch 27: val_loss did not improve from 1.05862
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 1.0571 - accuracy: 0.6958 - val_loss: 1.7213 - val_accuracy: 0.5203
# Epoch 28/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0390 - accuracy: 0.7034
# Epoch 28: val_loss did not improve from 1.05862
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.0390 - accuracy: 0.7034 - val_loss: 1.4193 - val_accuracy: 0.5938
# Epoch 29/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0293 - accuracy: 0.7062
# Epoch 29: val_loss did not improve from 1.05862
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 1.0293 - accuracy: 0.7062 - val_loss: 1.9770 - val_accuracy: 0.5059
# Epoch 30/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0066 - accuracy: 0.7156
# Epoch 30: val_loss did not improve from 1.05862
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 1.0066 - accuracy: 0.7156 - val_loss: 1.4152 - val_accuracy: 0.6303
# Epoch 31/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9994 - accuracy: 0.7210
# Epoch 31: val_loss improved from 1.05862 to 0.95069, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.9994 - accuracy: 0.7210 - val_loss: 0.9507 - val_accuracy: 0.7368
# Epoch 32/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9888 - accuracy: 0.7256
# Epoch 32: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.9888 - accuracy: 0.7256 - val_loss: 1.4454 - val_accuracy: 0.6294
# Epoch 33/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.9820 - accuracy: 0.7278
# Epoch 33: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9824 - accuracy: 0.7276 - val_loss: 0.9955 - val_accuracy: 0.7325
# Epoch 34/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9573 - accuracy: 0.7404
# Epoch 34: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9573 - accuracy: 0.7404 - val_loss: 0.9872 - val_accuracy: 0.7364
# Epoch 35/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9646 - accuracy: 0.7366
# Epoch 35: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.9646 - accuracy: 0.7366 - val_loss: 1.0199 - val_accuracy: 0.7236
# Epoch 36/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9560 - accuracy: 0.7422
# Epoch 36: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9560 - accuracy: 0.7422 - val_loss: 1.2359 - val_accuracy: 0.6565
# Epoch 37/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9390 - accuracy: 0.7469
# Epoch 37: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9390 - accuracy: 0.7469 - val_loss: 1.1522 - val_accuracy: 0.7180
# Epoch 38/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9413 - accuracy: 0.7467
# Epoch 38: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9413 - accuracy: 0.7467 - val_loss: 1.1895 - val_accuracy: 0.6641
# Epoch 39/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9317 - accuracy: 0.7515
# Epoch 39: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9317 - accuracy: 0.7515 - val_loss: 1.1399 - val_accuracy: 0.7229
# Epoch 40/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9207 - accuracy: 0.7572
# Epoch 40: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9207 - accuracy: 0.7572 - val_loss: 1.5934 - val_accuracy: 0.5976
# Epoch 41/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9177 - accuracy: 0.7591
# Epoch 41: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.9177 - accuracy: 0.7591 - val_loss: 1.1763 - val_accuracy: 0.6844
# Epoch 42/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9163 - accuracy: 0.7605
# Epoch 42: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.9163 - accuracy: 0.7605 - val_loss: 1.0277 - val_accuracy: 0.7366
# Epoch 43/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9077 - accuracy: 0.7633
# Epoch 43: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.9077 - accuracy: 0.7633 - val_loss: 1.4608 - val_accuracy: 0.6383
# Epoch 44/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9022 - accuracy: 0.7669
# Epoch 44: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.9022 - accuracy: 0.7669 - val_loss: 1.2346 - val_accuracy: 0.6796
# Epoch 45/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8991 - accuracy: 0.7675
# Epoch 45: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8991 - accuracy: 0.7675 - val_loss: 0.9993 - val_accuracy: 0.7442
# Epoch 46/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8922 - accuracy: 0.7711
# Epoch 46: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8922 - accuracy: 0.7711 - val_loss: 0.9988 - val_accuracy: 0.7480
# Epoch 47/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.8854 - accuracy: 0.7732
# Epoch 47: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8856 - accuracy: 0.7732 - val_loss: 1.1485 - val_accuracy: 0.7137
# Epoch 48/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8943 - accuracy: 0.7696
# Epoch 48: val_loss did not improve from 0.95069
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8943 - accuracy: 0.7696 - val_loss: 1.3205 - val_accuracy: 0.6590
# Epoch 49/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8843 - accuracy: 0.7769
# Epoch 49: val_loss improved from 0.95069 to 0.92177, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8843 - accuracy: 0.7769 - val_loss: 0.9218 - val_accuracy: 0.7737
# Epoch 50/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8742 - accuracy: 0.7785
# Epoch 50: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 100ms/step - loss: 0.8742 - accuracy: 0.7785 - val_loss: 1.1967 - val_accuracy: 0.6967
# Epoch 51/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8728 - accuracy: 0.7821
# Epoch 51: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8728 - accuracy: 0.7821 - val_loss: 0.9327 - val_accuracy: 0.7646
# Epoch 52/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.8700 - accuracy: 0.7812
# Epoch 52: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8698 - accuracy: 0.7813 - val_loss: 1.2566 - val_accuracy: 0.6874
# Epoch 53/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8593 - accuracy: 0.7855
# Epoch 53: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8593 - accuracy: 0.7855 - val_loss: 1.2963 - val_accuracy: 0.6657
# Epoch 54/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8732 - accuracy: 0.7811
# Epoch 54: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 100ms/step - loss: 0.8732 - accuracy: 0.7811 - val_loss: 1.1367 - val_accuracy: 0.7134
# Epoch 55/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8670 - accuracy: 0.7850
# Epoch 55: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 100ms/step - loss: 0.8670 - accuracy: 0.7850 - val_loss: 1.1770 - val_accuracy: 0.7114
# Epoch 56/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8550 - accuracy: 0.7897
# Epoch 56: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8550 - accuracy: 0.7897 - val_loss: 1.1662 - val_accuracy: 0.6940
# Epoch 57/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8547 - accuracy: 0.7906
# Epoch 57: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8547 - accuracy: 0.7906 - val_loss: 1.1247 - val_accuracy: 0.7185
# Epoch 58/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8478 - accuracy: 0.7929
# Epoch 58: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8478 - accuracy: 0.7929 - val_loss: 1.3150 - val_accuracy: 0.6819
# Epoch 59/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8474 - accuracy: 0.7934
# Epoch 59: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8474 - accuracy: 0.7934 - val_loss: 0.9525 - val_accuracy: 0.7769
# Epoch 60/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8462 - accuracy: 0.7933
# Epoch 60: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8462 - accuracy: 0.7933 - val_loss: 1.0609 - val_accuracy: 0.7511
# Epoch 61/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8481 - accuracy: 0.7934
# Epoch 61: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8481 - accuracy: 0.7934 - val_loss: 1.5027 - val_accuracy: 0.6296
# Epoch 62/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8441 - accuracy: 0.7953
# Epoch 62: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.8441 - accuracy: 0.7953 - val_loss: 0.9302 - val_accuracy: 0.7821
# Epoch 63/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8350 - accuracy: 0.7991
# Epoch 63: val_loss did not improve from 0.92177
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8350 - accuracy: 0.7991 - val_loss: 1.0292 - val_accuracy: 0.7433
# Epoch 64/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8351 - accuracy: 0.7988
# Epoch 64: val_loss improved from 0.92177 to 0.84949, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8351 - accuracy: 0.7988 - val_loss: 0.8495 - val_accuracy: 0.7998
# Epoch 65/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8303 - accuracy: 0.8017
# Epoch 65: val_loss improved from 0.84949 to 0.82562, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8303 - accuracy: 0.8017 - val_loss: 0.8256 - val_accuracy: 0.8120
# Epoch 66/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8355 - accuracy: 0.7985
# Epoch 66: val_loss did not improve from 0.82562
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8355 - accuracy: 0.7985 - val_loss: 1.2175 - val_accuracy: 0.7176
# Epoch 67/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8272 - accuracy: 0.8038
# Epoch 67: val_loss did not improve from 0.82562
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8272 - accuracy: 0.8038 - val_loss: 1.0136 - val_accuracy: 0.7556
# Epoch 68/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8180 - accuracy: 0.8061
# Epoch 68: val_loss did not improve from 0.82562
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.8180 - accuracy: 0.8061 - val_loss: 0.9849 - val_accuracy: 0.7832
# Epoch 69/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8198 - accuracy: 0.8055
# Epoch 69: val_loss did not improve from 0.82562
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8198 - accuracy: 0.8055 - val_loss: 1.0554 - val_accuracy: 0.7532
# Epoch 70/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8243 - accuracy: 0.8057
# Epoch 70: val_loss did not improve from 0.82562
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8243 - accuracy: 0.8057 - val_loss: 1.1600 - val_accuracy: 0.7226
# Epoch 71/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8111 - accuracy: 0.8107
# Epoch 71: val_loss improved from 0.82562 to 0.80389, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8111 - accuracy: 0.8107 - val_loss: 0.8039 - val_accuracy: 0.8208
# Epoch 72/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8155 - accuracy: 0.8061
# Epoch 72: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8155 - accuracy: 0.8061 - val_loss: 0.8468 - val_accuracy: 0.8017
# Epoch 73/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8107 - accuracy: 0.8104
# Epoch 73: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8107 - accuracy: 0.8104 - val_loss: 1.0984 - val_accuracy: 0.7335
# Epoch 74/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8111 - accuracy: 0.8109
# Epoch 74: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8111 - accuracy: 0.8109 - val_loss: 0.8830 - val_accuracy: 0.7904
# Epoch 75/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8137 - accuracy: 0.8083
# Epoch 75: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8137 - accuracy: 0.8083 - val_loss: 1.1554 - val_accuracy: 0.7194
# Epoch 76/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8059 - accuracy: 0.8124
# Epoch 76: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.8059 - accuracy: 0.8124 - val_loss: 1.4447 - val_accuracy: 0.6729
# Epoch 77/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8042 - accuracy: 0.8151
# Epoch 77: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.8042 - accuracy: 0.8151 - val_loss: 1.0018 - val_accuracy: 0.7653
# Epoch 78/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.8133
# Epoch 78: val_loss did not improve from 0.80389
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.8058 - accuracy: 0.8133 - val_loss: 1.1779 - val_accuracy: 0.7265
# Epoch 79/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7978 - accuracy: 0.8168
# Epoch 79: val_loss improved from 0.80389 to 0.75730, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.7978 - accuracy: 0.8168 - val_loss: 0.7573 - val_accuracy: 0.8404
# Epoch 80/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.8070 - accuracy: 0.8118
# Epoch 80: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.8070 - accuracy: 0.8119 - val_loss: 0.9264 - val_accuracy: 0.7915
# Epoch 81/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7929 - accuracy: 0.8183
# Epoch 81: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 39s 101ms/step - loss: 0.7929 - accuracy: 0.8183 - val_loss: 0.9576 - val_accuracy: 0.7735
# Epoch 82/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8029 - accuracy: 0.8152
# Epoch 82: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 104ms/step - loss: 0.8029 - accuracy: 0.8152 - val_loss: 1.0067 - val_accuracy: 0.7693
# Epoch 83/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7935 - accuracy: 0.8200
# Epoch 83: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7935 - accuracy: 0.8200 - val_loss: 0.8865 - val_accuracy: 0.8051
# Epoch 84/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7848 - accuracy: 0.8246
# Epoch 84: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7848 - accuracy: 0.8246 - val_loss: 1.1852 - val_accuracy: 0.7381
# Epoch 85/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7913 - accuracy: 0.8189
# Epoch 85: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.7913 - accuracy: 0.8189 - val_loss: 1.0074 - val_accuracy: 0.7771
# Epoch 86/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7862 - accuracy: 0.8233
# Epoch 86: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7862 - accuracy: 0.8233 - val_loss: 0.8648 - val_accuracy: 0.8107
# Epoch 87/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7866 - accuracy: 0.8207
# Epoch 87: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7866 - accuracy: 0.8207 - val_loss: 1.1696 - val_accuracy: 0.7238
# Epoch 88/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.8212
# Epoch 88: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.7907 - accuracy: 0.8212 - val_loss: 0.9377 - val_accuracy: 0.7841
# Epoch 89/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7825 - accuracy: 0.8233
# Epoch 89: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7825 - accuracy: 0.8233 - val_loss: 0.9596 - val_accuracy: 0.7853
# Epoch 90/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7800 - accuracy: 0.8245
# Epoch 90: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7800 - accuracy: 0.8245 - val_loss: 0.7647 - val_accuracy: 0.8378
# Epoch 91/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7797 - accuracy: 0.8240
# Epoch 91: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7797 - accuracy: 0.8240 - val_loss: 0.9760 - val_accuracy: 0.7891
# Epoch 92/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7822 - accuracy: 0.8254
# Epoch 92: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 103ms/step - loss: 0.7822 - accuracy: 0.8254 - val_loss: 1.2699 - val_accuracy: 0.7194
# Epoch 93/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7806 - accuracy: 0.8244
# Epoch 93: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7806 - accuracy: 0.8244 - val_loss: 0.9015 - val_accuracy: 0.7931
# Epoch 94/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7715 - accuracy: 0.8277
# Epoch 94: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7715 - accuracy: 0.8277 - val_loss: 1.2507 - val_accuracy: 0.7075
# Epoch 95/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7741 - accuracy: 0.8270
# Epoch 95: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7741 - accuracy: 0.8270 - val_loss: 0.8240 - val_accuracy: 0.8261
# Epoch 96/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7717 - accuracy: 0.8290
# Epoch 96: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7717 - accuracy: 0.8290 - val_loss: 0.9810 - val_accuracy: 0.7732
# Epoch 97/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7715 - accuracy: 0.8282
# Epoch 97: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.7715 - accuracy: 0.8282 - val_loss: 1.0128 - val_accuracy: 0.7721
# Epoch 98/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7767 - accuracy: 0.8284
# Epoch 98: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.7767 - accuracy: 0.8284 - val_loss: 0.9186 - val_accuracy: 0.8011
# Epoch 99/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.8309
# Epoch 99: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7711 - accuracy: 0.8309 - val_loss: 0.9212 - val_accuracy: 0.7906
# Epoch 100/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7685 - accuracy: 0.8320
# Epoch 100: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 102ms/step - loss: 0.7685 - accuracy: 0.8320 - val_loss: 0.7969 - val_accuracy: 0.8241
# Epoch 101/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7691 - accuracy: 0.8309
# Epoch 101: val_loss did not improve from 0.75730
#
# lr:1.00e-01
# 390/390 [==============================] - 40s 101ms/step - loss: 0.7691 - accuracy: 0.8309 - val_loss: 0.8183 - val_accuracy: 0.8275
# Epoch 102/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7644 - accuracy: 0.8316
# Epoch 102: val_loss did not improve from 0.75730
#
# lr:1.00e-02
# 390/390 [==============================] - 39s 101ms/step - loss: 0.7644 - accuracy: 0.8316 - val_loss: 0.8148 - val_accuracy: 0.8227
# Epoch 103/200
# 390/390 [==============================] - ETA: 0s - loss: 0.6759 - accuracy: 0.8641
# Epoch 103: val_loss improved from 0.75730 to 0.59423, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 41s 106ms/step - loss: 0.6759 - accuracy: 0.8641 - val_loss: 0.5942 - val_accuracy: 0.8945
# Epoch 104/200
# 390/390 [==============================] - ETA: 0s - loss: 0.6160 - accuracy: 0.8815
# Epoch 104: val_loss improved from 0.59423 to 0.58704, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 41s 104ms/step - loss: 0.6160 - accuracy: 0.8815 - val_loss: 0.5870 - val_accuracy: 0.8993
# Epoch 105/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5883 - accuracy: 0.8918
# Epoch 105: val_loss improved from 0.58704 to 0.58004, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.5883 - accuracy: 0.8918 - val_loss: 0.5800 - val_accuracy: 0.8983
# Epoch 106/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.8922
# Epoch 106: val_loss improved from 0.58004 to 0.55559, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.5792 - accuracy: 0.8922 - val_loss: 0.5556 - val_accuracy: 0.9068
# Epoch 107/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5654 - accuracy: 0.8964
# Epoch 107: val_loss improved from 0.55559 to 0.55392, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.5654 - accuracy: 0.8964 - val_loss: 0.5539 - val_accuracy: 0.9023
# Epoch 108/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5584 - accuracy: 0.8973
# Epoch 108: val_loss improved from 0.55392 to 0.55085, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.5584 - accuracy: 0.8973 - val_loss: 0.5509 - val_accuracy: 0.9089
# Epoch 109/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5406 - accuracy: 0.9014
# Epoch 109: val_loss did not improve from 0.55085
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.5406 - accuracy: 0.9014 - val_loss: 0.5524 - val_accuracy: 0.9066
# Epoch 110/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5264 - accuracy: 0.9049
# Epoch 110: val_loss improved from 0.55085 to 0.54059, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 41s 104ms/step - loss: 0.5264 - accuracy: 0.9049 - val_loss: 0.5406 - val_accuracy: 0.9064
# Epoch 111/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.5245 - accuracy: 0.9052
# Epoch 111: val_loss improved from 0.54059 to 0.53546, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.5244 - accuracy: 0.9052 - val_loss: 0.5355 - val_accuracy: 0.9082
# Epoch 112/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.5178 - accuracy: 0.9059
# Epoch 112: val_loss improved from 0.53546 to 0.52976, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.5178 - accuracy: 0.9060 - val_loss: 0.5298 - val_accuracy: 0.9110
# Epoch 113/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5077 - accuracy: 0.9094
# Epoch 113: val_loss did not improve from 0.52976
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.5077 - accuracy: 0.9094 - val_loss: 0.5324 - val_accuracy: 0.9079
# Epoch 114/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5028 - accuracy: 0.9073
# Epoch 114: val_loss improved from 0.52976 to 0.52549, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 41s 104ms/step - loss: 0.5028 - accuracy: 0.9073 - val_loss: 0.5255 - val_accuracy: 0.9106
# Epoch 115/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.9076
# Epoch 115: val_loss improved from 0.52549 to 0.51410, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.5006 - accuracy: 0.9076 - val_loss: 0.5141 - val_accuracy: 0.9103
# Epoch 116/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.9113
# Epoch 116: val_loss did not improve from 0.51410
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4853 - accuracy: 0.9113 - val_loss: 0.5149 - val_accuracy: 0.9128
# Epoch 117/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.9126
# Epoch 117: val_loss did not improve from 0.51410
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 101ms/step - loss: 0.4842 - accuracy: 0.9126 - val_loss: 0.5208 - val_accuracy: 0.9070
# Epoch 118/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.9113
# Epoch 118: val_loss did not improve from 0.51410
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4810 - accuracy: 0.9113 - val_loss: 0.5202 - val_accuracy: 0.9098
# Epoch 119/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.9144
# Epoch 119: val_loss improved from 0.51410 to 0.51099, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4694 - accuracy: 0.9144 - val_loss: 0.5110 - val_accuracy: 0.9093
# Epoch 120/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.9132
# Epoch 120: val_loss improved from 0.51099 to 0.49152, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4686 - accuracy: 0.9132 - val_loss: 0.4915 - val_accuracy: 0.9141
# Epoch 121/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.9154
# Epoch 121: val_loss improved from 0.49152 to 0.49031, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.4624 - accuracy: 0.9154 - val_loss: 0.4903 - val_accuracy: 0.9162
# Epoch 122/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.9174
# Epoch 122: val_loss did not improve from 0.49031
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4516 - accuracy: 0.9174 - val_loss: 0.4991 - val_accuracy: 0.9114
# Epoch 123/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.9136
# Epoch 123: val_loss improved from 0.49031 to 0.48880, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4541 - accuracy: 0.9136 - val_loss: 0.4888 - val_accuracy: 0.9130
# Epoch 124/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.9195
# Epoch 124: val_loss did not improve from 0.48880
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4428 - accuracy: 0.9195 - val_loss: 0.5133 - val_accuracy: 0.9075
# Epoch 125/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.9177
# Epoch 125: val_loss improved from 0.48880 to 0.48448, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.4430 - accuracy: 0.9177 - val_loss: 0.4845 - val_accuracy: 0.9120
# Epoch 126/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.4376 - accuracy: 0.9188
# Epoch 126: val_loss did not improve from 0.48448
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4375 - accuracy: 0.9189 - val_loss: 0.5249 - val_accuracy: 0.9016
# Epoch 127/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.9171
# Epoch 127: val_loss did not improve from 0.48448
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4387 - accuracy: 0.9171 - val_loss: 0.5166 - val_accuracy: 0.9028
# Epoch 128/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.9209
# Epoch 128: val_loss did not improve from 0.48448
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4271 - accuracy: 0.9209 - val_loss: 0.5053 - val_accuracy: 0.9083
# Epoch 129/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.9217
# Epoch 129: val_loss did not improve from 0.48448
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4241 - accuracy: 0.9217 - val_loss: 0.4886 - val_accuracy: 0.9129
# Epoch 130/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.4171 - accuracy: 0.9233
# Epoch 130: val_loss improved from 0.48448 to 0.47809, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4173 - accuracy: 0.9233 - val_loss: 0.4781 - val_accuracy: 0.9135
# Epoch 131/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4159 - accuracy: 0.9220
# Epoch 131: val_loss did not improve from 0.47809
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4159 - accuracy: 0.9220 - val_loss: 0.5082 - val_accuracy: 0.9082
# Epoch 132/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.9216
# Epoch 132: val_loss did not improve from 0.47809
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.4121 - accuracy: 0.9216 - val_loss: 0.4788 - val_accuracy: 0.9144
# Epoch 133/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.9204
# Epoch 133: val_loss improved from 0.47809 to 0.46888, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.4149 - accuracy: 0.9204 - val_loss: 0.4689 - val_accuracy: 0.9154
# Epoch 134/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.9241
# Epoch 134: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 101ms/step - loss: 0.4042 - accuracy: 0.9241 - val_loss: 0.4784 - val_accuracy: 0.9136
# Epoch 135/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.9242
# Epoch 135: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.4034 - accuracy: 0.9242 - val_loss: 0.4994 - val_accuracy: 0.9040
# Epoch 136/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4037 - accuracy: 0.9235
# Epoch 136: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 39s 101ms/step - loss: 0.4037 - accuracy: 0.9235 - val_loss: 0.4883 - val_accuracy: 0.9078
# Epoch 137/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.9245
# Epoch 137: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 39s 101ms/step - loss: 0.3993 - accuracy: 0.9245 - val_loss: 0.4711 - val_accuracy: 0.9113
# Epoch 138/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3983 - accuracy: 0.9231
# Epoch 138: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3983 - accuracy: 0.9231 - val_loss: 0.4707 - val_accuracy: 0.9130
# Epoch 139/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3928 - accuracy: 0.9258
# Epoch 139: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 39s 101ms/step - loss: 0.3928 - accuracy: 0.9258 - val_loss: 0.4910 - val_accuracy: 0.9077
# Epoch 140/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3872 - accuracy: 0.9271
# Epoch 140: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3872 - accuracy: 0.9271 - val_loss: 0.4776 - val_accuracy: 0.9117
# Epoch 141/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.9277
# Epoch 141: val_loss did not improve from 0.46888
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3826 - accuracy: 0.9277 - val_loss: 0.4757 - val_accuracy: 0.9095
# Epoch 142/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.9256
# Epoch 142: val_loss improved from 0.46888 to 0.45475, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 104ms/step - loss: 0.3862 - accuracy: 0.9256 - val_loss: 0.4548 - val_accuracy: 0.9139
# Epoch 143/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.9268
# Epoch 143: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3815 - accuracy: 0.9268 - val_loss: 0.4700 - val_accuracy: 0.9133
# Epoch 144/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.9261
# Epoch 144: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 101ms/step - loss: 0.3798 - accuracy: 0.9261 - val_loss: 0.4991 - val_accuracy: 0.9051
# Epoch 145/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3745 - accuracy: 0.9268
# Epoch 145: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3745 - accuracy: 0.9268 - val_loss: 0.4879 - val_accuracy: 0.9048
# Epoch 146/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.9249
# Epoch 146: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 39s 101ms/step - loss: 0.3812 - accuracy: 0.9249 - val_loss: 0.4629 - val_accuracy: 0.9137
# Epoch 147/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.9278
# Epoch 147: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3718 - accuracy: 0.9278 - val_loss: 0.4645 - val_accuracy: 0.9102
# Epoch 148/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.9275
# Epoch 148: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3717 - accuracy: 0.9275 - val_loss: 0.4704 - val_accuracy: 0.9099
# Epoch 149/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.9285
# Epoch 149: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3688 - accuracy: 0.9285 - val_loss: 0.4711 - val_accuracy: 0.9114
# Epoch 150/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.9277
# Epoch 150: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3707 - accuracy: 0.9277 - val_loss: 0.4889 - val_accuracy: 0.9041
# Epoch 151/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3653 - accuracy: 0.9276
# Epoch 151: val_loss did not improve from 0.45475
#
# lr:1.00e-02
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3653 - accuracy: 0.9276 - val_loss: 0.4960 - val_accuracy: 0.9046
# Epoch 152/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.9301
# Epoch 152: val_loss did not improve from 0.45475
#
# lr:1.00e-03
# 390/390 [==============================] - 39s 101ms/step - loss: 0.3610 - accuracy: 0.9301 - val_loss: 0.5293 - val_accuracy: 0.8968
# Epoch 153/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3441 - accuracy: 0.9356
# Epoch 153: val_loss improved from 0.45475 to 0.43303, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 41s 104ms/step - loss: 0.3441 - accuracy: 0.9356 - val_loss: 0.4330 - val_accuracy: 0.9208
# Epoch 154/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.9407
# Epoch 154: val_loss improved from 0.43303 to 0.42763, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3314 - accuracy: 0.9407 - val_loss: 0.4276 - val_accuracy: 0.9222
# Epoch 155/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.9423
# Epoch 155: val_loss improved from 0.42763 to 0.42753, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 41s 104ms/step - loss: 0.3278 - accuracy: 0.9423 - val_loss: 0.4275 - val_accuracy: 0.9230
# Epoch 156/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.9443
# Epoch 156: val_loss did not improve from 0.42753
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3207 - accuracy: 0.9443 - val_loss: 0.4287 - val_accuracy: 0.9239
# Epoch 157/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.9441
# Epoch 157: val_loss improved from 0.42753 to 0.42572, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3204 - accuracy: 0.9441 - val_loss: 0.4257 - val_accuracy: 0.9234
# Epoch 158/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.9452
# Epoch 158: val_loss did not improve from 0.42572
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3169 - accuracy: 0.9452 - val_loss: 0.4275 - val_accuracy: 0.9232
# Epoch 159/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.9470
# Epoch 159: val_loss improved from 0.42572 to 0.42376, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3140 - accuracy: 0.9470 - val_loss: 0.4238 - val_accuracy: 0.9238
# Epoch 160/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.9461
# Epoch 160: val_loss did not improve from 0.42376
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3127 - accuracy: 0.9461 - val_loss: 0.4277 - val_accuracy: 0.9231
# Epoch 161/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.9467
# Epoch 161: val_loss improved from 0.42376 to 0.42107, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 41s 104ms/step - loss: 0.3123 - accuracy: 0.9467 - val_loss: 0.4211 - val_accuracy: 0.9248
# Epoch 162/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.9459
# Epoch 162: val_loss did not improve from 0.42107
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3137 - accuracy: 0.9459 - val_loss: 0.4239 - val_accuracy: 0.9242
# Epoch 163/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9482
# Epoch 163: val_loss did not improve from 0.42107
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3083 - accuracy: 0.9482 - val_loss: 0.4252 - val_accuracy: 0.9237
# Epoch 164/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.9466
# Epoch 164: val_loss did not improve from 0.42107
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3100 - accuracy: 0.9466 - val_loss: 0.4222 - val_accuracy: 0.9251
# Epoch 165/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9477
# Epoch 165: val_loss improved from 0.42107 to 0.42024, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3069 - accuracy: 0.9477 - val_loss: 0.4202 - val_accuracy: 0.9248
# Epoch 166/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.9483
# Epoch 166: val_loss improved from 0.42024 to 0.41924, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3059 - accuracy: 0.9483 - val_loss: 0.4192 - val_accuracy: 0.9258
# Epoch 167/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.9488
# Epoch 167: val_loss improved from 0.41924 to 0.41704, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3023 - accuracy: 0.9488 - val_loss: 0.4170 - val_accuracy: 0.9275
# Epoch 168/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.9497
# Epoch 168: val_loss did not improve from 0.41704
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3026 - accuracy: 0.9497 - val_loss: 0.4282 - val_accuracy: 0.9247
# Epoch 169/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.3048 - accuracy: 0.9486
# Epoch 169: val_loss did not improve from 0.41704
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3048 - accuracy: 0.9486 - val_loss: 0.4217 - val_accuracy: 0.9259
# Epoch 170/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.9500
# Epoch 170: val_loss did not improve from 0.41704
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3000 - accuracy: 0.9500 - val_loss: 0.4188 - val_accuracy: 0.9250
# Epoch 171/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.9496
# Epoch 171: val_loss improved from 0.41704 to 0.41633, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 104ms/step - loss: 0.3021 - accuracy: 0.9496 - val_loss: 0.4163 - val_accuracy: 0.9267
# Epoch 172/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.9481
# Epoch 172: val_loss did not improve from 0.41633
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.3015 - accuracy: 0.9481 - val_loss: 0.4180 - val_accuracy: 0.9274
# Epoch 173/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.9502
# Epoch 173: val_loss did not improve from 0.41633
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 101ms/step - loss: 0.2990 - accuracy: 0.9502 - val_loss: 0.4193 - val_accuracy: 0.9259
# Epoch 174/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.9492
# Epoch 174: val_loss did not improve from 0.41633
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2997 - accuracy: 0.9492 - val_loss: 0.4182 - val_accuracy: 0.9264
# Epoch 175/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.9517
# Epoch 175: val_loss improved from 0.41633 to 0.41474, saving model to ResNet-for-CIFAR-10-with-Keras.h5
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2956 - accuracy: 0.9517 - val_loss: 0.4147 - val_accuracy: 0.9275
# Epoch 176/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.9492
# Epoch 176: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.3001 - accuracy: 0.9492 - val_loss: 0.4184 - val_accuracy: 0.9269
# Epoch 177/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.9510
# Epoch 177: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2951 - accuracy: 0.9510 - val_loss: 0.4178 - val_accuracy: 0.9263
# Epoch 178/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.9519
# Epoch 178: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2935 - accuracy: 0.9519 - val_loss: 0.4196 - val_accuracy: 0.9283
# Epoch 179/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.9510
# Epoch 179: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2964 - accuracy: 0.9510 - val_loss: 0.4187 - val_accuracy: 0.9270
# Epoch 180/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9514
# Epoch 180: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2954 - accuracy: 0.9514 - val_loss: 0.4190 - val_accuracy: 0.9261
# Epoch 181/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.9527
# Epoch 181: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2922 - accuracy: 0.9527 - val_loss: 0.4226 - val_accuracy: 0.9255
# Epoch 182/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.9518
# Epoch 182: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2934 - accuracy: 0.9518 - val_loss: 0.4236 - val_accuracy: 0.9273
# Epoch 183/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.9514
# Epoch 183: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2931 - accuracy: 0.9514 - val_loss: 0.4206 - val_accuracy: 0.9280
# Epoch 184/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9516
# Epoch 184: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 39s 101ms/step - loss: 0.2914 - accuracy: 0.9516 - val_loss: 0.4228 - val_accuracy: 0.9279
# Epoch 185/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2928 - accuracy: 0.9508
# Epoch 185: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2928 - accuracy: 0.9508 - val_loss: 0.4236 - val_accuracy: 0.9262
# Epoch 186/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.9530
# Epoch 186: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 39s 101ms/step - loss: 0.2889 - accuracy: 0.9530 - val_loss: 0.4205 - val_accuracy: 0.9275
# Epoch 187/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.9532
# Epoch 187: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2881 - accuracy: 0.9532 - val_loss: 0.4235 - val_accuracy: 0.9265
# Epoch 188/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.2870 - accuracy: 0.9533
# Epoch 188: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2871 - accuracy: 0.9533 - val_loss: 0.4311 - val_accuracy: 0.9250
# Epoch 189/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9515
# Epoch 189: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2913 - accuracy: 0.9515 - val_loss: 0.4228 - val_accuracy: 0.9284
# Epoch 190/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.9519
# Epoch 190: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2886 - accuracy: 0.9519 - val_loss: 0.4240 - val_accuracy: 0.9279
# Epoch 191/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.9521
# Epoch 191: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2861 - accuracy: 0.9521 - val_loss: 0.4248 - val_accuracy: 0.9266
# Epoch 192/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.9534
# Epoch 192: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2845 - accuracy: 0.9534 - val_loss: 0.4225 - val_accuracy: 0.9284
# Epoch 193/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.9535
# Epoch 193: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2868 - accuracy: 0.9535 - val_loss: 0.4218 - val_accuracy: 0.9260
# Epoch 194/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9525
# Epoch 194: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2872 - accuracy: 0.9525 - val_loss: 0.4280 - val_accuracy: 0.9251
# Epoch 195/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9540
# Epoch 195: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2835 - accuracy: 0.9540 - val_loss: 0.4222 - val_accuracy: 0.9280
# Epoch 196/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.9535
# Epoch 196: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2847 - accuracy: 0.9535 - val_loss: 0.4181 - val_accuracy: 0.9263
# Epoch 197/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.9538
# Epoch 197: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 39s 100ms/step - loss: 0.2825 - accuracy: 0.9538 - val_loss: 0.4242 - val_accuracy: 0.9251
# Epoch 198/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.9542
# Epoch 198: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 101ms/step - loss: 0.2843 - accuracy: 0.9542 - val_loss: 0.4228 - val_accuracy: 0.9277
# Epoch 199/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.9528
# Epoch 199: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 103ms/step - loss: 0.2847 - accuracy: 0.9528 - val_loss: 0.4221 - val_accuracy: 0.9263
# Epoch 200/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.9537
# Epoch 200: val_loss did not improve from 0.41474
#
# lr:1.00e-03
# 390/390 [==============================] - 40s 102ms/step - loss: 0.2815 - accuracy: 0.9537 - val_loss: 0.4227 - val_accuracy: 0.9263

# %%
# evaluate model
score = model.evaluate(x_test, 
                       y_test, 
                       batch_size=batch_size)

print("Original Accuracy: ",score)
# Out:
# 79/79 [==============================] - 3s 38ms/step - loss: 0.4225 - accuracy: 0.9263
# Original Accuracy:  [0.4224640727043152, 0.9262999892234802]

# %%
# save model
model_type = dataset + "--" + model_arch
model_instance = model_type + "-" + str(seed)
model_filename = model_instance + ".h5"
model_subdir = pathlib.Path(MODELS_FOLDER / model.name)
pathlib.Path(model_subdir).mkdir(parents=True, exist_ok=True)
model_file = str(pathlib.Path(model_subdir/ model_filename))
model.save(model_file)

# %%
model.summary()
# Out:
# Model: "resnet_lrs_checkpnt_cutout56"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_12[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 16)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['add_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   544         ['activation_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['conv2d_21[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 32)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 32)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 32)   0           ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['activation_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_28[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 16, 16, 32)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['add_15[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 16, 16, 32)   0           ['activation_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_34 (Activation)     (None, 16, 16, 32)   0           ['add_16[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 16, 16, 32)   0           ['activation_34[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 32)   0           ['add_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 64)     0           ['conv2d_40[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['add_18[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 64)     0           ['activation_38[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['add_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 64)     0           ['activation_40[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['add_20[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 8, 8, 64)     0           ['activation_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['add_21[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 8, 8, 64)     0           ['activation_44[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['add_22[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 8, 8, 64)     0           ['activation_46[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 64)     0           ['add_23[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 64)    256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 8, 8, 64)     0           ['activation_48[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_50 (Activation)     (None, 8, 8, 64)     0           ['add_24[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 64)    256         ['conv2d_54[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 8, 8, 64)     0           ['activation_50[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_52 (Activation)     (None, 8, 8, 64)     0           ['add_25[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 64)    256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 64)    256         ['conv2d_56[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 8, 8, 64)     0           ['activation_52[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  activation_54 (Activation)     (None, 8, 8, 64)     0           ['add_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_54[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 64)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 10)           650         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
