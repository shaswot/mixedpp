# %%
# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb

# %%
import os
import sys
import git
import pathlib

import random

import numpy as np
import tensorflow as tf
from tensorflow import keras

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

from libs.constants import MODELS_FOLDER

# %%
# Limit GPU growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
import libs.model_archs
import libs.utils
from libs.seeds import load_model_seeds
model_seeds = load_model_seeds()

# %%
# define dataset and model architecture
dataset = "cifar10"
# Select ResNet Version
resnet_version = 1
model_arch = "resnetA" + str(resnet_version)

# set training hyperparameters
batch_size = 128
n_epochs = 200

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()
# ZCA whiteningなどを行う場合が以下の実行が必要
# datagen.fit(train_x)
# datagen_for_test.fit(test_x)

# %%
# global seed
seed = model_seeds[0]
tf.random.set_seed(seed)
np.random.seed(seed)

# prepare data
# dataset_loader = getattr(libs.utils, 'prepare_'+dataset)
# to_categorical=False
# (x_train, y_train), (x_test, y_test) = dataset_loader(to_categorical)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

dataset_test = (x_test, y_test) 
dataset_train = (x_train, y_train)

x_train = dataset_train[0] / 255
y_train = dataset_train[1].squeeze()
x_test = dataset_test[0] / 255
y_test = dataset_test[1].squeeze()

number_train = x_train.shape[0]
number_test = x_test.shape[0]

# %%
from tensorflow.keras.callbacks import Callback
class LearningController(Callback):
    def __init__(self, num_epoch=0, learn_minute=0):
        self.num_epoch = num_epoch
        self.learn_second = learn_minute * 60
        if self.learn_second > 0:
            print("Learning rate is controled by time.")
        elif self.num_epoch > 0:
            print("Learning rate is controled by epoch.")
        
    def on_train_begin(self, logs=None):
        if self.learn_second > 0:
            self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        if self.learn_second > 0:
            current_time = time.time()
            if current_time - self.start_time > self.learn_second:
                self.model.stop_training = True
                print("Time is up.")
                return

            if current_time - self.start_time > self.learn_second / 2:
                self.model.optimizer.lr = lr * 0.1            
            if current_time - self.start_time > self.learn_second * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                
        elif self.num_epoch > 0:
            if epoch > self.num_epoch / 2:
                self.model.optimizer.lr = lr * 0.1            
            if epoch > self.num_epoch * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                    
        print('\nlr:%.2e' % self.model.optimizer.lr.value())

# %%
# create model
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2


input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
n_classes = y_train.shape

# n_channels = x_train.shape[3] # no. of channels (?)
# # Computed depth of model
# if resnet_version == 1:
# 	depth = n_channels * 6 + 2
# elif resnet_version == 2:
# 	depth = n_channels * 9 + 2

# model_generator = getattr(libs.model_archs, model_arch)
# model = model_generator(input_shape, depth, n_classes)

# https://github.com/shoji9x9/CIFAR-10-By-small-ResNet/blob/master/ResNet-for-CIFAR-10-with-Keras.ipynb
n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=input_shape)
x = Conv2D(channels[0], 
           kernel_size=(3, 3), 
           padding="same", 
           kernel_initializer="he_normal", 
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   strides=strides, 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, 
                   kernel_size=(3, 3), 
                   padding="same", 
                   kernel_initializer="he_normal", 
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if subsampling:
            x = Conv2D(c, 
                       kernel_size=(1, 1), 
                       strides=(2, 2), 
                       padding="same", 
                       kernel_initializer="he_normal", 
                       kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, 
                activation=tf.nn.softmax, 
                kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)

model._name = "resnet_lrs_cutout" + str(6 * n + 2)

# %%
# from tensorflow.keras.callbacks import ModelCheckpoint
# checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", 
#                              monitor="val_loss", 
#                              verbose=1, 
#                              save_best_only=True)

# %%
# compile model
from tensorflow.keras.optimizers import SGD
# model.compile(loss ='categorical_crossentropy',
#               optimizer ='adam',
#               metrics =['accuracy'])
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, 
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"])

learning_controller = LearningController(n_epochs)
callbacks = [learning_controller]
# train model
model.fit(datagen.flow(x_train, 
                         y_train, 
                         batch_size=batch_size), 
          epochs=n_epochs,
          steps_per_epoch=number_train//batch_size,
          validation_data=datagen_for_test.flow(x_test, 
                                                  y_test, 
                                                  batch_size=batch_size),
          validation_steps=number_test//batch_size,
          validation_split=0.2,
          callbacks=callbacks)
# Out:
# Learning rate is controled by epoch.
# Epoch 1/200
# 390/390 [==============================] - ETA: 0s - loss: 2.8987 - accuracy: 0.1411
# lr:1.00e-01
# 390/390 [==============================] - 38s 63ms/step - loss: 2.8987 - accuracy: 0.1411 - val_loss: 2.5783 - val_accuracy: 0.2045
# Epoch 2/200
# 390/390 [==============================] - ETA: 0s - loss: 2.2763 - accuracy: 0.3096
# lr:1.00e-01
# 390/390 [==============================] - 24s 60ms/step - loss: 2.2763 - accuracy: 0.3096 - val_loss: 2.4086 - val_accuracy: 0.3150
# Epoch 3/200
# 390/390 [==============================] - ETA: 0s - loss: 2.0295 - accuracy: 0.3955
# lr:1.00e-01
# 390/390 [==============================] - 24s 61ms/step - loss: 2.0295 - accuracy: 0.3955 - val_loss: 2.3113 - val_accuracy: 0.3438
# Epoch 4/200
# 390/390 [==============================] - ETA: 0s - loss: 1.9009 - accuracy: 0.4296
# lr:1.00e-01
# 390/390 [==============================] - 24s 62ms/step - loss: 1.9009 - accuracy: 0.4296 - val_loss: 2.3291 - val_accuracy: 0.3483
# Epoch 5/200
# 390/390 [==============================] - ETA: 0s - loss: 1.8209 - accuracy: 0.4471
# lr:1.00e-01
# 390/390 [==============================] - 24s 61ms/step - loss: 1.8209 - accuracy: 0.4471 - val_loss: 1.9983 - val_accuracy: 0.3842
# Epoch 6/200
# 390/390 [==============================] - ETA: 0s - loss: 1.7427 - accuracy: 0.4627
# lr:1.00e-01
# 390/390 [==============================] - 24s 61ms/step - loss: 1.7427 - accuracy: 0.4627 - val_loss: 2.0461 - val_accuracy: 0.3915
# Epoch 7/200
# 390/390 [==============================] - ETA: 0s - loss: 1.6650 - accuracy: 0.4818
# lr:1.00e-01
# 390/390 [==============================] - 23s 60ms/step - loss: 1.6650 - accuracy: 0.4818 - val_loss: 1.5698 - val_accuracy: 0.5132
# Epoch 8/200
# 390/390 [==============================] - ETA: 0s - loss: 1.5780 - accuracy: 0.5092
# lr:1.00e-01
# 390/390 [==============================] - 24s 61ms/step - loss: 1.5780 - accuracy: 0.5092 - val_loss: 1.9085 - val_accuracy: 0.4189
# Epoch 9/200
# 390/390 [==============================] - ETA: 0s - loss: 1.5135 - accuracy: 0.5285
# lr:1.00e-01
# 390/390 [==============================] - 24s 61ms/step - loss: 1.5135 - accuracy: 0.5285 - val_loss: 1.6692 - val_accuracy: 0.5065
# Epoch 10/200
# 390/390 [==============================] - ETA: 0s - loss: 1.4293 - accuracy: 0.5601
# lr:1.00e-01
# 390/390 [==============================] - 23s 60ms/step - loss: 1.4293 - accuracy: 0.5601 - val_loss: 1.5334 - val_accuracy: 0.5502
# Epoch 11/200
# 390/390 [==============================] - ETA: 0s - loss: 1.3629 - accuracy: 0.5798
# lr:1.00e-01
# 390/390 [==============================] - 27s 70ms/step - loss: 1.3629 - accuracy: 0.5798 - val_loss: 1.8878 - val_accuracy: 0.4880
# Epoch 12/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2973 - accuracy: 0.6042
# lr:1.00e-01
# 390/390 [==============================] - 29s 74ms/step - loss: 1.2973 - accuracy: 0.6042 - val_loss: 2.0694 - val_accuracy: 0.4501
# Epoch 13/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2430 - accuracy: 0.6213
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 1.2430 - accuracy: 0.6213 - val_loss: 1.6763 - val_accuracy: 0.5309
# Epoch 14/200
# 390/390 [==============================] - ETA: 0s - loss: 1.2021 - accuracy: 0.6368
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.2021 - accuracy: 0.6368 - val_loss: 1.5837 - val_accuracy: 0.5535
# Epoch 15/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1593 - accuracy: 0.6530
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.1593 - accuracy: 0.6530 - val_loss: 1.6686 - val_accuracy: 0.5474
# Epoch 16/200
# 390/390 [==============================] - ETA: 0s - loss: 1.1214 - accuracy: 0.6682
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.1214 - accuracy: 0.6682 - val_loss: 1.1880 - val_accuracy: 0.6594
# Epoch 17/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0820 - accuracy: 0.6819
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.0820 - accuracy: 0.6819 - val_loss: 1.6759 - val_accuracy: 0.5458
# Epoch 18/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0533 - accuracy: 0.6931
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.0533 - accuracy: 0.6931 - val_loss: 1.3751 - val_accuracy: 0.6260
# Epoch 19/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0320 - accuracy: 0.7010
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 1.0320 - accuracy: 0.7010 - val_loss: 0.9991 - val_accuracy: 0.7276
# Epoch 20/200
# 390/390 [==============================] - ETA: 0s - loss: 1.0145 - accuracy: 0.7100
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 1.0145 - accuracy: 0.7100 - val_loss: 1.0240 - val_accuracy: 0.7197
# Epoch 21/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9905 - accuracy: 0.7180
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.9905 - accuracy: 0.7180 - val_loss: 1.2351 - val_accuracy: 0.6772
# Epoch 22/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9745 - accuracy: 0.7245
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.9745 - accuracy: 0.7245 - val_loss: 0.9259 - val_accuracy: 0.7549
# Epoch 23/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9527 - accuracy: 0.7323
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.9527 - accuracy: 0.7323 - val_loss: 1.3419 - val_accuracy: 0.6244
# Epoch 24/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9396 - accuracy: 0.7379
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.9396 - accuracy: 0.7379 - val_loss: 1.5345 - val_accuracy: 0.6030
# Epoch 25/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.7449
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.9260 - accuracy: 0.7449 - val_loss: 1.2775 - val_accuracy: 0.6584
# Epoch 26/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9188 - accuracy: 0.7495
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.9188 - accuracy: 0.7495 - val_loss: 1.0252 - val_accuracy: 0.7329
# Epoch 27/200
# 390/390 [==============================] - ETA: 0s - loss: 0.9093 - accuracy: 0.7515
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.9093 - accuracy: 0.7515 - val_loss: 1.7526 - val_accuracy: 0.5454
# Epoch 28/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8971 - accuracy: 0.7584
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8971 - accuracy: 0.7584 - val_loss: 1.1826 - val_accuracy: 0.6861
# Epoch 29/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8776 - accuracy: 0.7673
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8776 - accuracy: 0.7673 - val_loss: 1.0950 - val_accuracy: 0.7148
# Epoch 30/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8775 - accuracy: 0.7660
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8775 - accuracy: 0.7660 - val_loss: 0.9860 - val_accuracy: 0.7431
# Epoch 31/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8688 - accuracy: 0.7693
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8688 - accuracy: 0.7693 - val_loss: 1.0696 - val_accuracy: 0.7175
# Epoch 32/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8637 - accuracy: 0.7735
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8637 - accuracy: 0.7735 - val_loss: 1.0937 - val_accuracy: 0.7255
# Epoch 33/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8604 - accuracy: 0.7738
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8604 - accuracy: 0.7738 - val_loss: 0.9012 - val_accuracy: 0.7706
# Epoch 34/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8546 - accuracy: 0.7795
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8546 - accuracy: 0.7795 - val_loss: 0.9480 - val_accuracy: 0.7565
# Epoch 35/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8482 - accuracy: 0.7805
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8482 - accuracy: 0.7805 - val_loss: 1.8346 - val_accuracy: 0.5980
# Epoch 36/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8455 - accuracy: 0.7828
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8455 - accuracy: 0.7828 - val_loss: 1.0979 - val_accuracy: 0.7219
# Epoch 37/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8276 - accuracy: 0.7884
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8276 - accuracy: 0.7884 - val_loss: 0.8687 - val_accuracy: 0.7832
# Epoch 38/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8285 - accuracy: 0.7908
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8285 - accuracy: 0.7908 - val_loss: 0.8963 - val_accuracy: 0.7795
# Epoch 39/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8197 - accuracy: 0.7930
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8197 - accuracy: 0.7930 - val_loss: 0.8062 - val_accuracy: 0.8058
# Epoch 40/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8149 - accuracy: 0.7951
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8149 - accuracy: 0.7951 - val_loss: 1.1452 - val_accuracy: 0.7321
# Epoch 41/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8188 - accuracy: 0.7941
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8188 - accuracy: 0.7941 - val_loss: 0.8652 - val_accuracy: 0.7882
# Epoch 42/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.7993
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8068 - accuracy: 0.7993 - val_loss: 1.0328 - val_accuracy: 0.7544
# Epoch 43/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8106 - accuracy: 0.7999
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8106 - accuracy: 0.7999 - val_loss: 1.1779 - val_accuracy: 0.7183
# Epoch 44/200
# 390/390 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.8021
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8058 - accuracy: 0.8021 - val_loss: 0.9801 - val_accuracy: 0.7614
# Epoch 45/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7977 - accuracy: 0.8049
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7977 - accuracy: 0.8049 - val_loss: 1.0350 - val_accuracy: 0.7427
# Epoch 46/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7984 - accuracy: 0.8039
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7984 - accuracy: 0.8039 - val_loss: 1.4300 - val_accuracy: 0.6472
# Epoch 47/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.8082
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7903 - accuracy: 0.8082 - val_loss: 0.9612 - val_accuracy: 0.7759
# Epoch 48/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7976 - accuracy: 0.8064
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7976 - accuracy: 0.8064 - val_loss: 0.8953 - val_accuracy: 0.7901
# Epoch 49/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7887 - accuracy: 0.8087
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7887 - accuracy: 0.8087 - val_loss: 0.8734 - val_accuracy: 0.7913
# Epoch 50/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7835 - accuracy: 0.8101
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7835 - accuracy: 0.8101 - val_loss: 1.0542 - val_accuracy: 0.7592
# Epoch 51/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7815 - accuracy: 0.8138
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7815 - accuracy: 0.8138 - val_loss: 1.5750 - val_accuracy: 0.6575
# Epoch 52/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7831 - accuracy: 0.8125
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7831 - accuracy: 0.8125 - val_loss: 1.0823 - val_accuracy: 0.7329
# Epoch 53/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7775 - accuracy: 0.8156
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7775 - accuracy: 0.8156 - val_loss: 1.0633 - val_accuracy: 0.7439
# Epoch 54/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7758 - accuracy: 0.8162
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7758 - accuracy: 0.8162 - val_loss: 0.9302 - val_accuracy: 0.7675
# Epoch 55/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7769 - accuracy: 0.8177
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7769 - accuracy: 0.8177 - val_loss: 0.8865 - val_accuracy: 0.7843
# Epoch 56/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7708 - accuracy: 0.8178
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7708 - accuracy: 0.8178 - val_loss: 1.0025 - val_accuracy: 0.7555
# Epoch 57/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7701 - accuracy: 0.8203
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7701 - accuracy: 0.8203 - val_loss: 1.0387 - val_accuracy: 0.7636
# Epoch 58/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7691 - accuracy: 0.8206
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7691 - accuracy: 0.8206 - val_loss: 1.4815 - val_accuracy: 0.6697
# Epoch 59/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7704 - accuracy: 0.8217
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7704 - accuracy: 0.8217 - val_loss: 0.9540 - val_accuracy: 0.7752
# Epoch 60/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7630 - accuracy: 0.8238
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7630 - accuracy: 0.8238 - val_loss: 0.9759 - val_accuracy: 0.7661
# Epoch 61/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7655 - accuracy: 0.8223
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7655 - accuracy: 0.8223 - val_loss: 0.9973 - val_accuracy: 0.7652
# Epoch 62/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7664 - accuracy: 0.8249
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7664 - accuracy: 0.8249 - val_loss: 0.8198 - val_accuracy: 0.8174
# Epoch 63/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7598 - accuracy: 0.8262
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7598 - accuracy: 0.8262 - val_loss: 1.1688 - val_accuracy: 0.7476
# Epoch 64/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7639 - accuracy: 0.8247
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7639 - accuracy: 0.8247 - val_loss: 0.9630 - val_accuracy: 0.7815
# Epoch 65/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7607 - accuracy: 0.8276
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7607 - accuracy: 0.8276 - val_loss: 1.0026 - val_accuracy: 0.7803
# Epoch 66/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7591 - accuracy: 0.8264
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7591 - accuracy: 0.8264 - val_loss: 0.8851 - val_accuracy: 0.8078
# Epoch 67/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7548 - accuracy: 0.8288
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7548 - accuracy: 0.8288 - val_loss: 1.0145 - val_accuracy: 0.7715
# Epoch 68/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7478 - accuracy: 0.8337
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7478 - accuracy: 0.8337 - val_loss: 0.7704 - val_accuracy: 0.8334
# Epoch 69/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.8317
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7473 - accuracy: 0.8317 - val_loss: 0.7953 - val_accuracy: 0.8261
# Epoch 70/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7607 - accuracy: 0.8294
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7607 - accuracy: 0.8294 - val_loss: 0.9850 - val_accuracy: 0.7694
# Epoch 71/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.8330
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.7470 - accuracy: 0.8330 - val_loss: 0.9502 - val_accuracy: 0.7884
# Epoch 72/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7508 - accuracy: 0.8326
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.7508 - accuracy: 0.8326 - val_loss: 0.8199 - val_accuracy: 0.8207
# Epoch 73/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.8349
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7443 - accuracy: 0.8349 - val_loss: 0.9850 - val_accuracy: 0.7823
# Epoch 74/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7423 - accuracy: 0.8360
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7423 - accuracy: 0.8360 - val_loss: 1.5600 - val_accuracy: 0.6753
# Epoch 75/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7452 - accuracy: 0.8360
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7452 - accuracy: 0.8360 - val_loss: 0.9078 - val_accuracy: 0.8112
# Epoch 76/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7373 - accuracy: 0.8381
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7373 - accuracy: 0.8381 - val_loss: 0.9462 - val_accuracy: 0.7920
# Epoch 77/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.8395
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7374 - accuracy: 0.8395 - val_loss: 0.7377 - val_accuracy: 0.8440
# Epoch 78/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7435 - accuracy: 0.8336
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7435 - accuracy: 0.8336 - val_loss: 1.1109 - val_accuracy: 0.7569
# Epoch 79/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7433 - accuracy: 0.8358
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7433 - accuracy: 0.8358 - val_loss: 0.7945 - val_accuracy: 0.8281
# Epoch 80/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7410 - accuracy: 0.8378
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7410 - accuracy: 0.8378 - val_loss: 0.7883 - val_accuracy: 0.8349
# Epoch 81/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7346 - accuracy: 0.8394
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7346 - accuracy: 0.8394 - val_loss: 0.8401 - val_accuracy: 0.8151
# Epoch 82/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7462 - accuracy: 0.8374
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7462 - accuracy: 0.8374 - val_loss: 1.2626 - val_accuracy: 0.7084
# Epoch 83/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7356 - accuracy: 0.8403
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.7356 - accuracy: 0.8403 - val_loss: 0.8582 - val_accuracy: 0.8137
# Epoch 84/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7372 - accuracy: 0.8412
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7372 - accuracy: 0.8412 - val_loss: 0.9473 - val_accuracy: 0.7846
# Epoch 85/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7336 - accuracy: 0.8435
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7336 - accuracy: 0.8435 - val_loss: 0.7338 - val_accuracy: 0.8527
# Epoch 86/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.8436
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7273 - accuracy: 0.8436 - val_loss: 0.9346 - val_accuracy: 0.8013
# Epoch 87/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7302 - accuracy: 0.8416
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7302 - accuracy: 0.8416 - val_loss: 0.8794 - val_accuracy: 0.8097
# Epoch 88/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.8435
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7325 - accuracy: 0.8435 - val_loss: 0.7496 - val_accuracy: 0.8444
# Epoch 89/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7264 - accuracy: 0.8430
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7264 - accuracy: 0.8430 - val_loss: 0.9318 - val_accuracy: 0.8028
# Epoch 90/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.8459
# lr:1.00e-01
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7256 - accuracy: 0.8459 - val_loss: 0.9302 - val_accuracy: 0.8063
# Epoch 91/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7303 - accuracy: 0.8450
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7303 - accuracy: 0.8450 - val_loss: 0.8194 - val_accuracy: 0.8242
# Epoch 92/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.8473
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7190 - accuracy: 0.8473 - val_loss: 0.8911 - val_accuracy: 0.8076
# Epoch 93/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7310 - accuracy: 0.8421
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7310 - accuracy: 0.8421 - val_loss: 0.7683 - val_accuracy: 0.8359
# Epoch 94/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.8484
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7200 - accuracy: 0.8484 - val_loss: 0.8807 - val_accuracy: 0.8088
# Epoch 95/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.8465
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7221 - accuracy: 0.8465 - val_loss: 0.7655 - val_accuracy: 0.8462
# Epoch 96/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7202 - accuracy: 0.8456
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7202 - accuracy: 0.8456 - val_loss: 0.8176 - val_accuracy: 0.8303
# Epoch 97/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.8468
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7198 - accuracy: 0.8468 - val_loss: 1.0311 - val_accuracy: 0.7845
# Epoch 98/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.8487
# lr:1.00e-01
# 390/390 [==============================] - 29s 76ms/step - loss: 0.7216 - accuracy: 0.8487 - val_loss: 0.7677 - val_accuracy: 0.8422
# Epoch 99/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.8467
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7219 - accuracy: 0.8467 - val_loss: 0.8328 - val_accuracy: 0.8259
# Epoch 100/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.8485
# lr:1.00e-01
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7216 - accuracy: 0.8485 - val_loss: 0.9391 - val_accuracy: 0.7948
# Epoch 101/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7218 - accuracy: 0.8489
# lr:1.00e-01
# 390/390 [==============================] - 30s 77ms/step - loss: 0.7218 - accuracy: 0.8489 - val_loss: 0.8722 - val_accuracy: 0.8150
# Epoch 102/200
# 390/390 [==============================] - ETA: 0s - loss: 0.7207 - accuracy: 0.8486
# lr:1.00e-02
# 390/390 [==============================] - 29s 75ms/step - loss: 0.7207 - accuracy: 0.8486 - val_loss: 0.8640 - val_accuracy: 0.8204
# Epoch 103/200
# 390/390 [==============================] - ETA: 0s - loss: 0.6274 - accuracy: 0.8807
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.6274 - accuracy: 0.8807 - val_loss: 0.5533 - val_accuracy: 0.9107
# Epoch 104/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.8984
# lr:1.00e-02
# 390/390 [==============================] - 29s 76ms/step - loss: 0.5727 - accuracy: 0.8984 - val_loss: 0.5442 - val_accuracy: 0.9145
# Epoch 105/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5503 - accuracy: 0.9042
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5503 - accuracy: 0.9042 - val_loss: 0.5465 - val_accuracy: 0.9109
# Epoch 106/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5353 - accuracy: 0.9088
# lr:1.00e-02
# 390/390 [==============================] - 29s 76ms/step - loss: 0.5353 - accuracy: 0.9088 - val_loss: 0.5222 - val_accuracy: 0.9200
# Epoch 107/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.9106
# lr:1.00e-02
# 390/390 [==============================] - 29s 76ms/step - loss: 0.5207 - accuracy: 0.9106 - val_loss: 0.5255 - val_accuracy: 0.9150
# Epoch 108/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5142 - accuracy: 0.9118
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5142 - accuracy: 0.9118 - val_loss: 0.5048 - val_accuracy: 0.9215
# Epoch 109/200
# 390/390 [==============================] - ETA: 0s - loss: 0.5003 - accuracy: 0.9158
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5003 - accuracy: 0.9158 - val_loss: 0.5139 - val_accuracy: 0.9189
# Epoch 110/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4909 - accuracy: 0.9175
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4909 - accuracy: 0.9175 - val_loss: 0.5104 - val_accuracy: 0.9164
# Epoch 111/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.9179
# lr:1.00e-02
# 390/390 [==============================] - 29s 75ms/step - loss: 0.4862 - accuracy: 0.9179 - val_loss: 0.4935 - val_accuracy: 0.9232
# Epoch 112/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.9212
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4767 - accuracy: 0.9212 - val_loss: 0.4911 - val_accuracy: 0.9207
# Epoch 113/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4704 - accuracy: 0.9219
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4704 - accuracy: 0.9219 - val_loss: 0.4989 - val_accuracy: 0.9201
# Epoch 114/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.9231
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4622 - accuracy: 0.9231 - val_loss: 0.4944 - val_accuracy: 0.9198
# Epoch 115/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4587 - accuracy: 0.9236
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4587 - accuracy: 0.9236 - val_loss: 0.4697 - val_accuracy: 0.9252
# Epoch 116/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.9255
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4496 - accuracy: 0.9255 - val_loss: 0.4837 - val_accuracy: 0.9232
# Epoch 117/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4396 - accuracy: 0.9273
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4396 - accuracy: 0.9273 - val_loss: 0.4957 - val_accuracy: 0.9174
# Epoch 118/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.9256
# lr:1.00e-02
# 390/390 [==============================] - 29s 75ms/step - loss: 0.4412 - accuracy: 0.9256 - val_loss: 0.4882 - val_accuracy: 0.9187
# Epoch 119/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.9275
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4326 - accuracy: 0.9275 - val_loss: 0.4631 - val_accuracy: 0.9247
# Epoch 120/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.9294
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4269 - accuracy: 0.9294 - val_loss: 0.4811 - val_accuracy: 0.9203
# Epoch 121/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.9299
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4220 - accuracy: 0.9299 - val_loss: 0.4587 - val_accuracy: 0.9281
# Epoch 122/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.9309
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4161 - accuracy: 0.9309 - val_loss: 0.4626 - val_accuracy: 0.9236
# Epoch 123/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.9309
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4153 - accuracy: 0.9309 - val_loss: 0.4598 - val_accuracy: 0.9229
# Epoch 124/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.9320
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4060 - accuracy: 0.9320 - val_loss: 0.4574 - val_accuracy: 0.9227
# Epoch 125/200
# 390/390 [==============================] - ETA: 0s - loss: 0.4075 - accuracy: 0.9307
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4075 - accuracy: 0.9307 - val_loss: 0.4373 - val_accuracy: 0.9296
# Epoch 126/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3969 - accuracy: 0.9335
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3969 - accuracy: 0.9335 - val_loss: 0.4485 - val_accuracy: 0.9234
# Epoch 127/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.9314
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3986 - accuracy: 0.9314 - val_loss: 0.4825 - val_accuracy: 0.9144
# Epoch 128/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.9334
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3907 - accuracy: 0.9334 - val_loss: 0.4548 - val_accuracy: 0.9214
# Epoch 129/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3888 - accuracy: 0.9329
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3888 - accuracy: 0.9329 - val_loss: 0.4499 - val_accuracy: 0.9222
# Epoch 130/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.9372
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3772 - accuracy: 0.9372 - val_loss: 0.4516 - val_accuracy: 0.9211
# Epoch 131/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.9357
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3769 - accuracy: 0.9357 - val_loss: 0.4534 - val_accuracy: 0.9226
# Epoch 132/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3758 - accuracy: 0.9352
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3758 - accuracy: 0.9352 - val_loss: 0.4492 - val_accuracy: 0.9230
# Epoch 133/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.9350
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3765 - accuracy: 0.9350 - val_loss: 0.4308 - val_accuracy: 0.9262
# Epoch 134/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.9382
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3649 - accuracy: 0.9382 - val_loss: 0.4518 - val_accuracy: 0.9243
# Epoch 135/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.9362
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3673 - accuracy: 0.9362 - val_loss: 0.4219 - val_accuracy: 0.9267
# Epoch 136/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.9396
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3583 - accuracy: 0.9396 - val_loss: 0.4362 - val_accuracy: 0.9239
# Epoch 137/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.9372
# lr:1.00e-02
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3604 - accuracy: 0.9372 - val_loss: 0.4218 - val_accuracy: 0.9257
# Epoch 138/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3530 - accuracy: 0.9404
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3530 - accuracy: 0.9404 - val_loss: 0.4534 - val_accuracy: 0.9161
# Epoch 139/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3524 - accuracy: 0.9398
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3524 - accuracy: 0.9398 - val_loss: 0.4711 - val_accuracy: 0.9126
# Epoch 140/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3532 - accuracy: 0.9391
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3532 - accuracy: 0.9391 - val_loss: 0.4656 - val_accuracy: 0.9168
# Epoch 141/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.9430
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3422 - accuracy: 0.9430 - val_loss: 0.4502 - val_accuracy: 0.9192
# Epoch 142/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3496 - accuracy: 0.9398
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3496 - accuracy: 0.9398 - val_loss: 0.4410 - val_accuracy: 0.9211
# Epoch 143/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.9386
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3451 - accuracy: 0.9386 - val_loss: 0.4915 - val_accuracy: 0.9114
# Epoch 144/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.9422
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3378 - accuracy: 0.9422 - val_loss: 0.4444 - val_accuracy: 0.9177
# Epoch 145/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3395 - accuracy: 0.9395
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3395 - accuracy: 0.9395 - val_loss: 0.4539 - val_accuracy: 0.9183
# Epoch 146/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.9394
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3409 - accuracy: 0.9394 - val_loss: 0.4549 - val_accuracy: 0.9183
# Epoch 147/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.9414
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3329 - accuracy: 0.9414 - val_loss: 0.4515 - val_accuracy: 0.9150
# Epoch 148/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.9415
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3332 - accuracy: 0.9415 - val_loss: 0.4442 - val_accuracy: 0.9199
# Epoch 149/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3302 - accuracy: 0.9419
# lr:1.00e-02
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3302 - accuracy: 0.9419 - val_loss: 0.4470 - val_accuracy: 0.9178
# Epoch 150/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.9403
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3322 - accuracy: 0.9403 - val_loss: 0.4562 - val_accuracy: 0.9158
# Epoch 151/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.9421
# lr:1.00e-02
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3223 - accuracy: 0.9421 - val_loss: 0.4145 - val_accuracy: 0.9268
# Epoch 152/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.9412
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3249 - accuracy: 0.9412 - val_loss: 0.4550 - val_accuracy: 0.9157
# Epoch 153/200
# 390/390 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.9474
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.3106 - accuracy: 0.9474 - val_loss: 0.3835 - val_accuracy: 0.9317
# Epoch 154/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.9518
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2961 - accuracy: 0.9518 - val_loss: 0.3782 - val_accuracy: 0.9352
# Epoch 155/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.9537
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2917 - accuracy: 0.9537 - val_loss: 0.3833 - val_accuracy: 0.9338
# Epoch 156/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9552
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2872 - accuracy: 0.9552 - val_loss: 0.3823 - val_accuracy: 0.9341
# Epoch 157/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9560
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2842 - accuracy: 0.9560 - val_loss: 0.3794 - val_accuracy: 0.9372
# Epoch 158/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2836 - accuracy: 0.9568
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2836 - accuracy: 0.9568 - val_loss: 0.3777 - val_accuracy: 0.9356
# Epoch 159/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9553
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2852 - accuracy: 0.9553 - val_loss: 0.3779 - val_accuracy: 0.9367
# Epoch 160/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9573
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2819 - accuracy: 0.9573 - val_loss: 0.3826 - val_accuracy: 0.9341
# Epoch 161/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.9569
# lr:1.00e-03
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2816 - accuracy: 0.9569 - val_loss: 0.3770 - val_accuracy: 0.9343
# Epoch 162/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.9580
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2780 - accuracy: 0.9580 - val_loss: 0.3756 - val_accuracy: 0.9365
# Epoch 163/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.9592
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2753 - accuracy: 0.9592 - val_loss: 0.3778 - val_accuracy: 0.9364
# Epoch 164/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.9594
# lr:1.00e-03
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2759 - accuracy: 0.9594 - val_loss: 0.3811 - val_accuracy: 0.9334
# Epoch 165/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9580
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2767 - accuracy: 0.9580 - val_loss: 0.3818 - val_accuracy: 0.9359
# Epoch 166/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9595
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2723 - accuracy: 0.9595 - val_loss: 0.3791 - val_accuracy: 0.9357
# Epoch 167/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.9595
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2719 - accuracy: 0.9595 - val_loss: 0.3784 - val_accuracy: 0.9383
# Epoch 168/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9590
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2708 - accuracy: 0.9590 - val_loss: 0.3835 - val_accuracy: 0.9344
# Epoch 169/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9603
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2725 - accuracy: 0.9603 - val_loss: 0.3800 - val_accuracy: 0.9372
# Epoch 170/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2697 - accuracy: 0.9607
# lr:1.00e-03
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2697 - accuracy: 0.9607 - val_loss: 0.3779 - val_accuracy: 0.9364
# Epoch 171/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9602
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2677 - accuracy: 0.9602 - val_loss: 0.3768 - val_accuracy: 0.9381
# Epoch 172/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9615
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2666 - accuracy: 0.9615 - val_loss: 0.3765 - val_accuracy: 0.9380
# Epoch 173/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9604
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2681 - accuracy: 0.9604 - val_loss: 0.3769 - val_accuracy: 0.9383
# Epoch 174/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2675 - accuracy: 0.9597
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2675 - accuracy: 0.9597 - val_loss: 0.3796 - val_accuracy: 0.9381
# Epoch 175/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9605
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2664 - accuracy: 0.9605 - val_loss: 0.3729 - val_accuracy: 0.9389
# Epoch 176/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2675 - accuracy: 0.9603
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2675 - accuracy: 0.9603 - val_loss: 0.3795 - val_accuracy: 0.9364
# Epoch 177/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.9622
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2645 - accuracy: 0.9622 - val_loss: 0.3771 - val_accuracy: 0.9385
# Epoch 178/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9619
# lr:1.00e-03
# 390/390 [==============================] - 31s 79ms/step - loss: 0.2622 - accuracy: 0.9619 - val_loss: 0.3792 - val_accuracy: 0.9358
# Epoch 179/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.9620
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2635 - accuracy: 0.9620 - val_loss: 0.3760 - val_accuracy: 0.9375
# Epoch 180/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.9603
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2673 - accuracy: 0.9603 - val_loss: 0.3733 - val_accuracy: 0.9377
# Epoch 181/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.9629
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2612 - accuracy: 0.9629 - val_loss: 0.3743 - val_accuracy: 0.9385
# Epoch 182/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.9630
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2624 - accuracy: 0.9630 - val_loss: 0.3777 - val_accuracy: 0.9364
# Epoch 183/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2573 - accuracy: 0.9638
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2573 - accuracy: 0.9638 - val_loss: 0.3800 - val_accuracy: 0.9365
# Epoch 184/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9625
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2588 - accuracy: 0.9625 - val_loss: 0.3736 - val_accuracy: 0.9376
# Epoch 185/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.9615
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2634 - accuracy: 0.9615 - val_loss: 0.3723 - val_accuracy: 0.9385
# Epoch 186/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9638
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2570 - accuracy: 0.9638 - val_loss: 0.3760 - val_accuracy: 0.9365
# Epoch 187/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.9617
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2603 - accuracy: 0.9617 - val_loss: 0.3754 - val_accuracy: 0.9378
# Epoch 188/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9644
# lr:1.00e-03
# 390/390 [==============================] - 31s 79ms/step - loss: 0.2567 - accuracy: 0.9644 - val_loss: 0.3775 - val_accuracy: 0.9380
# Epoch 189/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.9641
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2579 - accuracy: 0.9641 - val_loss: 0.3775 - val_accuracy: 0.9375
# Epoch 190/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.9644
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2545 - accuracy: 0.9644 - val_loss: 0.3786 - val_accuracy: 0.9374
# Epoch 191/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9643
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2544 - accuracy: 0.9643 - val_loss: 0.3771 - val_accuracy: 0.9387
# Epoch 192/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2539 - accuracy: 0.9639
# lr:1.00e-03
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2539 - accuracy: 0.9639 - val_loss: 0.3749 - val_accuracy: 0.9382
# Epoch 193/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9635
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2570 - accuracy: 0.9635 - val_loss: 0.3744 - val_accuracy: 0.9382
# Epoch 194/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9639
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2544 - accuracy: 0.9639 - val_loss: 0.3775 - val_accuracy: 0.9364
# Epoch 195/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9630
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2558 - accuracy: 0.9630 - val_loss: 0.3781 - val_accuracy: 0.9369
# Epoch 196/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.9634
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2564 - accuracy: 0.9634 - val_loss: 0.3799 - val_accuracy: 0.9369
# Epoch 197/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.9637
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2514 - accuracy: 0.9637 - val_loss: 0.3732 - val_accuracy: 0.9386
# Epoch 198/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2522 - accuracy: 0.9643
# lr:1.00e-03
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2522 - accuracy: 0.9643 - val_loss: 0.3717 - val_accuracy: 0.9393
# Epoch 199/200
# 390/390 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9647
# lr:1.00e-03
# 390/390 [==============================] - 29s 75ms/step - loss: 0.2507 - accuracy: 0.9647 - val_loss: 0.3775 - val_accuracy: 0.9375
# Epoch 200/200
# 389/390 [============================>.] - ETA: 0s - loss: 0.2527 - accuracy: 0.9637
# lr:1.00e-03
# 390/390 [==============================] - 22s 57ms/step - loss: 0.2527 - accuracy: 0.9637 - val_loss: 0.3741 - val_accuracy: 0.9391

# %%
# evaluate model
score = model.evaluate(x_test, 
                       y_test, 
                       batch_size=batch_size)

print("Original Accuracy: ",score)
# Out:
# 79/79 [==============================] - 1s 17ms/step - loss: 0.3737 - accuracy: 0.9392
# Original Accuracy:  [0.37372899055480957, 0.9391999840736389]

# %%
# save model
model_type = dataset + "--" + model_arch
model_instance = model_type + "-" + str(seed)
model_filename = model_instance + ".h5"
model_subdir = pathlib.Path(MODELS_FOLDER / model.name)
pathlib.Path(model_subdir).mkdir(parents=True, exist_ok=True)
model_file = str(pathlib.Path(model_subdir/ model_filename))
model.save(model_file)

# %%
model.summary()
# Out:
# Model: "resnet_lrs_cutout56"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_12[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 16)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['add_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   544         ['activation_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['conv2d_21[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 32)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 32)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 32)   0           ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['activation_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_28[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 16, 16, 32)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['add_15[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 16, 16, 32)   0           ['activation_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_34 (Activation)     (None, 16, 16, 32)   0           ['add_16[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 16, 16, 32)   0           ['activation_34[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 32)   0           ['add_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 64)     0           ['conv2d_40[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['add_18[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 64)     0           ['activation_38[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['add_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 64)     0           ['activation_40[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['add_20[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 8, 8, 64)     0           ['activation_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['add_21[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 8, 8, 64)     0           ['activation_44[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['add_22[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 8, 8, 64)     0           ['activation_46[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 64)     0           ['add_23[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 64)    256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 8, 8, 64)     0           ['activation_48[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_50 (Activation)     (None, 8, 8, 64)     0           ['add_24[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 64)    256         ['conv2d_54[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 8, 8, 64)     0           ['activation_50[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_52 (Activation)     (None, 8, 8, 64)     0           ['add_25[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 64)    256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 64)    256         ['conv2d_56[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 8, 8, 64)     0           ['activation_52[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  activation_54 (Activation)     (None, 8, 8, 64)     0           ['add_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_54[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 64)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 10)           650         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
